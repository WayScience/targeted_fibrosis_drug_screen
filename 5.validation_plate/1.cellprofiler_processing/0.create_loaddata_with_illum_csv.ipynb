# %% [markdown]
# # Create CellProfiler LoadData CSV with Illumination Functions
#
# Create a CellProfiler `LoadData` CSV from raw image paths including paths to the illumination correction functions per channel. Each row is one image set, grouped by plate, well, and site, with one filename/path pair per Cell Painting channel and paths to illumination functions (npy).
#
# Channel mapping from the main repository README:
#
# | Image channel | CellProfiler image name |
# | --- | --- |
# | d0 | OrigActin |
# | d1 | OrigMito |
# | d2 | OrigGolgi |
# | d3 | OrigER |
# | d4 | OrigDNA |

# %%
from pathlib import Path

import sys

sys.path.append("../../utils")
import loaddata_csv

# %% [markdown]
# ## Set paths and variables

# %%
# Set path to find original loaddata csv files
orig_loaddata_csvs = Path("../0.illumination_correction/loaddata_csvs").resolve()

# Set output directory for loaddata csvs
output_dir = Path("loaddata_csvs")
output_dir.mkdir(exist_ok=True)

# Set path for illum_directory
illum_directory = Path("../0.illumination_correction/illum_directory")

# Set channel mapping to assign name in LoadData CSV
CHANNEL_MAP = {
    "d0": "OrigActin",
    "d1": "OrigMito",
    "d2": "OrigGolgi",
    "d3": "OrigER",
    "d4": "OrigDNA",
}

# %% [markdown]
# ## Update and save the LoadData CSV with illumination function columns

# %%
updated_dfs = loaddata_csv.add_illumination_columns_to_loaddata_csvs(
    loaddata_csv_paths=list(orig_loaddata_csvs.rglob("loaddata_*.csv")),
    illum_directory=illum_directory,
    channel_map=CHANNEL_MAP,
    output_dir=output_dir,
)

# Print one plate example
display(next(iter(updated_dfs.values())).head())
# Out:
#                  Metadata_Plate Metadata_Well  Metadata_Site  \
# 0  CARD-CelIns-CX7_260803130001           B02              0
# 1  CARD-CelIns-CX7_260803130001           B02              1
# 2  CARD-CelIns-CX7_260803130001           B02              2
# 3  CARD-CelIns-CX7_260803130001           B02              3
# 4  CARD-CelIns-CX7_260803130001           B02              4
#
#                           FileName_OrigActin  \
# 0  CARD-CelIns-CX7_260803130001_B02f00d0.TIF
# 1  CARD-CelIns-CX7_260803130001_B02f01d0.TIF
# 2  CARD-CelIns-CX7_260803130001_B02f02d0.TIF
# 3  CARD-CelIns-CX7_260803130001_B02f03d0.TIF
# 4  CARD-CelIns-CX7_260803130001_B02f04d0.TIF
#
#                            FileName_OrigMito  \
# 0  CARD-CelIns-CX7_260803130001_B02f00d1.TIF
# 1  CARD-CelIns-CX7_260803130001_B02f01d1.TIF
# 2  CARD-CelIns-CX7_260803130001_B02f02d1.TIF
# 3  CARD-CelIns-CX7_260803130001_B02f03d1.TIF
# 4  CARD-CelIns-CX7_260803130001_B02f04d1.TIF
#
#                           FileName_OrigGolgi  \
# 0  CARD-CelIns-CX7_260803130001_B02f00d2.TIF
# 1  CARD-CelIns-CX7_260803130001_B02f01d2.TIF
# 2  CARD-CelIns-CX7_260803130001_B02f02d2.TIF
# 3  CARD-CelIns-CX7_260803130001_B02f03d2.TIF
# 4  CARD-CelIns-CX7_260803130001_B02f04d2.TIF
#
#                              FileName_OrigER  \
# 0  CARD-CelIns-CX7_260803130001_B02f00d3.TIF
# 1  CARD-CelIns-CX7_260803130001_B02f01d3.TIF
# 2  CARD-CelIns-CX7_260803130001_B02f02d3.TIF
# 3  CARD-CelIns-CX7_260803130001_B02f03d3.TIF
# 4  CARD-CelIns-CX7_260803130001_B02f04d3.TIF
#
#                             FileName_OrigDNA  \
# 0  CARD-CelIns-CX7_260803130001_B02f00d4.TIF
# 1  CARD-CelIns-CX7_260803130001_B02f01d4.TIF
# 2  CARD-CelIns-CX7_260803130001_B02f02d4.TIF
# 3  CARD-CelIns-CX7_260803130001_B02f03d4.TIF
# 4  CARD-CelIns-CX7_260803130001_B02f04d4.TIF
#
#                                   PathName_OrigActin  \
# 0  /home/jenna/mnt/Way_McKinsey_Cardiac_Fibrosis/...
# 1  /home/jenna/mnt/Way_McKinsey_Cardiac_Fibrosis/...
# 2  /home/jenna/mnt/Way_McKinsey_Cardiac_Fibrosis/...
# 3  /home/jenna/mnt/Way_McKinsey_Cardiac_Fibrosis/...
# 4  /home/jenna/mnt/Way_McKinsey_Cardiac_Fibrosis/...
#
#                                    PathName_OrigMito  ...  \
# 0  /home/jenna/mnt/Way_McKinsey_Cardiac_Fibrosis/...  ...
# 1  /home/jenna/mnt/Way_McKinsey_Cardiac_Fibrosis/...  ...
# 2  /home/jenna/mnt/Way_McKinsey_Cardiac_Fibrosis/...  ...
# 3  /home/jenna/mnt/Way_McKinsey_Cardiac_Fibrosis/...  ...
# 4  /home/jenna/mnt/Way_McKinsey_Cardiac_Fibrosis/...  ...
#
#                            FileName_IllumActin  \
# 0  CARD-CelIns-CX7_260803130001_IllumActin.npy
# 1  CARD-CelIns-CX7_260803130001_IllumActin.npy
# 2  CARD-CelIns-CX7_260803130001_IllumActin.npy
# 3  CARD-CelIns-CX7_260803130001_IllumActin.npy
# 4  CARD-CelIns-CX7_260803130001_IllumActin.npy
#
#                                  PathName_IllumActin  \
# 0  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 1  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 2  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 3  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 4  /home/jenna/targeted_fibrosis_drug_screen/5.va...
#
#                            FileName_IllumMito  \
# 0  CARD-CelIns-CX7_260803130001_IllumMito.npy
# 1  CARD-CelIns-CX7_260803130001_IllumMito.npy
# 2  CARD-CelIns-CX7_260803130001_IllumMito.npy
# 3  CARD-CelIns-CX7_260803130001_IllumMito.npy
# 4  CARD-CelIns-CX7_260803130001_IllumMito.npy
#
#                                   PathName_IllumMito  \
# 0  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 1  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 2  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 3  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 4  /home/jenna/targeted_fibrosis_drug_screen/5.va...
#
#                            FileName_IllumGolgi  \
# 0  CARD-CelIns-CX7_260803130001_IllumGolgi.npy
# 1  CARD-CelIns-CX7_260803130001_IllumGolgi.npy
# 2  CARD-CelIns-CX7_260803130001_IllumGolgi.npy
# 3  CARD-CelIns-CX7_260803130001_IllumGolgi.npy
# 4  CARD-CelIns-CX7_260803130001_IllumGolgi.npy
#
#                                  PathName_IllumGolgi  \
# 0  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 1  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 2  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 3  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 4  /home/jenna/targeted_fibrosis_drug_screen/5.va...
#
#                            FileName_IllumER  \
# 0  CARD-CelIns-CX7_260803130001_IllumER.npy
# 1  CARD-CelIns-CX7_260803130001_IllumER.npy
# 2  CARD-CelIns-CX7_260803130001_IllumER.npy
# 3  CARD-CelIns-CX7_260803130001_IllumER.npy
# 4  CARD-CelIns-CX7_260803130001_IllumER.npy
#
#                                     PathName_IllumER  \
# 0  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 1  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 2  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 3  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 4  /home/jenna/targeted_fibrosis_drug_screen/5.va...
#
#                            FileName_IllumDNA  \
# 0  CARD-CelIns-CX7_260803130001_IllumDNA.npy
# 1  CARD-CelIns-CX7_260803130001_IllumDNA.npy
# 2  CARD-CelIns-CX7_260803130001_IllumDNA.npy
# 3  CARD-CelIns-CX7_260803130001_IllumDNA.npy
# 4  CARD-CelIns-CX7_260803130001_IllumDNA.npy
#
#                                    PathName_IllumDNA
# 0  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 1  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 2  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 3  /home/jenna/targeted_fibrosis_drug_screen/5.va...
# 4  /home/jenna/targeted_fibrosis_drug_screen/5.va...
#
# [5 rows x 23 columns]
