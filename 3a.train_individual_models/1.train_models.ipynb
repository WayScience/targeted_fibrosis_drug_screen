# %% [markdown]
# ## Train machine learning models to predict failing or healthy cell status
#
# Each model will be trained on an individual plate or all plates from a batch combined.

# %% [markdown]
# ## Import libraries

# %%
import pathlib
import pprint
import sys
import warnings

import numpy as np
import pandas as pd
from joblib import dump
from sklearn.base import clone
from sklearn.exceptions import ConvergenceWarning
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import parallel_backend

sys.path.append("../utils")
from training_utils import downsample_data, get_X_y_data

# %% [markdown]
# ## Set paths and variables

# %%
# set numpy seed to make sure any random operations performs are reproducible
np.random.seed(0)

# path to training/testing datasets
training_data_path = pathlib.Path("./data")

# Find all training datasets
training_files = list(training_data_path.glob("*_train.parquet"))

# Metadata column used for prediction class
label = "Metadata_cell_type"

# Directory for models to be outputted
model_dir = pathlib.Path("./models")
model_dir.mkdir(exist_ok=True, parents=True)

# Directory for label encoder
encoder_dir = pathlib.Path("./encoder_results")
encoder_dir.mkdir(exist_ok=True, parents=True)

# Directory for training indices
training_indices_dir = pathlib.Path("./training_indices")
training_indices_dir.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# ## Load in training data

# %%
# Load in all training files as dataframes and store them under 'orig_train_df'
training_data_dfs_dict = {
    "_".join(parts[:2]) if parts[0] == "combined" else parts[0]: {
        "orig_train_df": pd.read_parquet(file)
    }
    for file in training_files
    if (parts := pathlib.Path(file).stem.split("_"))
}

# Pretty print the dictionary
pprint.pprint(training_data_dfs_dict, indent=4)
# Out:
# {   'combined_batch1': {   'orig_train_df':      Metadata_WellRow  Metadata_WellCol  Metadata_heart_number  \
# 0                   B                 2                      7
# 1                   E                 2                     19
# 2                   E                 2                     19
# 3                   E                 2                     19
# 4                   E                 2                     19
# ...               ...               ...                    ...
# 9281                E                 5                     19
# 9282                E                 8                     19
# 9283                E                11                     19
# 9284                E                 2                     19
# 9285                E                 5                     19
#
#      Metadata_cell_type Metadata_heart_failure_type Metadata_treatment  \
# 0               healthy                        None               DMSO
# 1               failing      dilated_cardiomyopathy               DMSO
# 2               failing      dilated_cardiomyopathy               DMSO
# 3               failing      dilated_cardiomyopathy               DMSO
# 4               failing      dilated_cardiomyopathy               DMSO
# ...                 ...                         ...                ...
# 9281            failing      dilated_cardiomyopathy               DMSO
# 9282            failing      dilated_cardiomyopathy               DMSO
# 9283            failing      dilated_cardiomyopathy               DMSO
# 9284            failing      dilated_cardiomyopathy               DMSO
# 9285            failing      dilated_cardiomyopathy               DMSO
#
#      Metadata_Pathway  Metadata_Nuclei_Location_Center_X  \
# 0                None                         586.110856
# 1                None                         544.012459
# 2                None                         767.384844
# 3                None                         937.835383
# 4                None                         940.066440
# ...               ...                                ...
# 9281             None                         390.257206
# 9282             None                         396.414134
# 9283             None                         220.698826
# 9284             None                         366.675090
# 9285             None                         574.426578
#
#       Metadata_Nuclei_Location_Center_Y  Metadata_Cells_Location_Center_X  \
# 0                            272.986789                        585.812571
# 1                           1015.857049                        540.169864
# 2                            203.437593                        777.096195
# 3                            725.915984                        892.558337
# 4                            420.071550                        924.417976
# ...                                 ...                               ...
# 9281                         466.450850                        394.785143
# 9282                         369.415548                        360.831378
# 9283                         645.753956                        260.821365
# 9284                         623.008123                        393.107978
# 9285                         395.988704                        597.986015
#
#       ...  Nuclei_Texture_InfoMeas2_PM_3_03_256  \
# 0     ...                             -0.097983
# 1     ...                             -1.011017
# 2     ...                             -0.769505
# 3     ...                              0.380650
# 4     ...                             -0.848936
# ...   ...                                   ...
# 9281  ...                             -1.527432
# 9282  ...                             -0.512720
# 9283  ...                             -0.352555
# 9284  ...                              0.595612
# 9285  ...                             -0.257834
#
#       Nuclei_Texture_InverseDifferenceMoment_Hoechst_3_00_256  \
# 0                                              0.686213
# 1                                             -1.032992
# 2                                             -1.469561
# 3                                              0.876283
# 4                                              0.756230
# ...                                                 ...
# 9281                                          -0.236825
# 9282                                          -0.883905
# 9283                                           0.834654
# 9284                                           2.633638
# 9285                                          -0.295451
#
#       Nuclei_Texture_InverseDifferenceMoment_Hoechst_3_01_256  \
# 0                                              0.099200
# 1                                             -0.807072
# 2                                              0.443859
# 3                                             -0.108488
# 4                                              1.225858
# ...                                                 ...
# 9281                                          -0.884379
# 9282                                          -0.760337
# 9283                                           0.870535
# 9284                                           2.139364
# 9285                                           0.880069
#
#      Nuclei_Texture_InverseDifferenceMoment_Hoechst_3_02_256  \
# 0                                              0.346359
# 1                                              0.540309
# 2                                             -1.336991
# 3                                             -0.453235
# 4                                              0.875755
# ...                                                 ...
# 9281                                          -0.814902
# 9282                                          -0.488261
# 9283                                           0.841141
# 9284                                           1.996552
# 9285                                          -0.526575
#
#      Nuclei_Texture_InverseDifferenceMoment_Hoechst_3_03_256  \
# 0                                              0.410444
# 1                                             -0.993311
# 2                                             -1.940503
# 3                                              0.588815
# 4                                              0.919894
# ...                                                 ...
# 9281                                          -0.598381
# 9282                                           0.018340
# 9283                                           0.523990
# 9284                                           2.034124
# 9285                                          -1.130257
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_00_256  \
# 0                                              0.592052
# 1                                              0.464286
# 2                                             -0.463749
# 3                                              0.258823
# 4                                              0.741930
# ...                                                 ...
# 9281                                           0.574086
# 9282                                          -0.044201
# 9283                                           0.167042
# 9284                                           1.466575
# 9285                                          -0.151928
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_01_256  \
# 0                                              0.660238
# 1                                              0.844515
# 2                                              0.336024
# 3                                              0.417707
# 4                                              1.372527
# ...                                                 ...
# 9281                                           0.892161
# 9282                                           0.119553
# 9283                                           0.392555
# 9284                                           1.370836
# 9285                                           0.946456
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_02_256  \
# 0                                              0.824522
# 1                                              0.388414
# 2                                             -0.436134
# 3                                             -0.923615
# 4                                              0.573394
# ...                                                 ...
# 9281                                           0.651185
# 9282                                          -0.076334
# 9283                                           0.205097
# 9284                                           1.180855
# 9285                                          -0.652955
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_03_256  \
# 0                                              0.602509
# 1                                              0.188370
# 2                                             -1.128984
# 3                                             -1.161158
# 4                                             -0.009191
# ...                                                 ...
# 9281                                           0.561321
# 9282                                           0.638935
# 9283                                          -0.082868
# 9284                                           1.100033
# 9285                                          -1.150707
#
#      Nuclei_Texture_SumEntropy_PM_3_01_256
# 0                                -0.493653
# 1                                -0.576802
# 2                                 0.109277
# 3                                 0.552393
# 4                                -0.265120
# ...                                    ...
# 9281                             -1.013204
# 9282                             -0.858859
# 9283                             -0.017979
# 9284                             -0.568766
# 9285                              0.292219
#
# [9286 rows x 494 columns]},
#     'localhost240926150001': {   'orig_train_df':       Metadata_WellRow  Metadata_WellCol  Metadata_heart_number  \
# 10353                E                11                     19
# 8571                 E                 5                     19
# 9725                 E                 8                     19
# 10594                E                11                     19
# 69                   B                 2                      7
# ...                ...               ...                    ...
# 7443                 E                 2                     19
# 9763                 E                 8                     19
# 10640                E                11                     19
# 7475                 E                 2                     19
# 10485                E                11                     19
#
#       Metadata_cell_type Metadata_heart_failure_type Metadata_treatment  \
# 10353            failing      dilated_cardiomyopathy               DMSO
# 8571             failing      dilated_cardiomyopathy               DMSO
# 9725             failing      dilated_cardiomyopathy               DMSO
# 10594            failing      dilated_cardiomyopathy               DMSO
# 69               healthy                        None               DMSO
# ...                  ...                         ...                ...
# 7443             failing      dilated_cardiomyopathy               DMSO
# 9763             failing      dilated_cardiomyopathy               DMSO
# 10640            failing      dilated_cardiomyopathy               DMSO
# 7475             failing      dilated_cardiomyopathy               DMSO
# 10485            failing      dilated_cardiomyopathy               DMSO
#
#       Metadata_Pathway  Metadata_Nuclei_Location_Center_X  \
# 10353             None                         165.518285
# 8571              None                         732.539768
# 9725              None                         474.510215
# 10594             None                         767.760972
# 69                None                         257.286759
# ...                ...                                ...
# 7443              None                         929.201777
# 9763              None                         488.291113
# 10640             None                         694.428145
# 7475              None                         569.384247
# 10485             None                         455.864516
#
#        Metadata_Nuclei_Location_Center_Y  Metadata_Cells_Location_Center_X  \
# 10353                         215.093590                        190.138818
# 8571                          381.359073                        755.511818
# 9725                          873.864516                        453.531945
# 10594                         835.677245                        742.031387
# 69                            544.465475                        222.625958
# ...                                  ...                               ...
# 7443                          243.346053                        975.406066
# 9763                          931.902029                        457.040811
# 10640                         548.987568                        653.935345
# 7475                          342.463012                        562.180640
# 10485                         338.150000                        473.416934
#
#        ...  Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_01_256  \
# 10353  ...                                          -2.192787
# 8571   ...                                          -0.382065
# 9725   ...                                           0.223007
# 10594  ...                                           0.500169
# 69     ...                                          -1.103604
# ...    ...                                                ...
# 7443   ...                                          -0.361073
# 9763   ...                                          -0.298840
# 10640  ...                                           0.739238
# 7475   ...                                           0.306198
# 10485  ...                                           0.589920
#
#        Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_03_256  \
# 10353                                          -0.116819
# 8571                                           -0.474732
# 9725                                            0.598604
# 10594                                          -1.039365
# 69                                             -0.060875
# ...                                                  ...
# 7443                                           -0.157931
# 9763                                            0.434801
# 10640                                           0.411904
# 7475                                            0.340218
# 10485                                          -0.013201
#
#        Nuclei_Texture_InverseDifferenceMoment_PM_3_00_256  \
# 10353                                          -1.363044
# 8571                                           -0.287040
# 9725                                            1.069825
# 10594                                           0.063924
# 69                                             -0.395267
# ...                                                  ...
# 7443                                           -0.854438
# 9763                                            0.638142
# 10640                                           1.213118
# 7475                                            0.216032
# 10485                                           0.959430
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_01_256  \
# 10353                                          -2.277173
# 8571                                           -0.118270
# 9725                                            1.104642
# 10594                                           1.244532
# 69                                             -0.301908
# ...                                                  ...
# 7443                                           -0.624173
# 9763                                           -0.016190
# 10640                                           1.333955
# 7475                                            0.085123
# 10485                                           1.524542
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_02_256  \
# 10353                                          -1.802169
# 8571                                            0.640681
# 9725                                            0.781923
# 10594                                           0.506054
# 69                                             -0.050702
# ...                                                  ...
# 7443                                           -0.878581
# 9763                                            0.206294
# 10640                                           1.254594
# 7475                                            0.341270
# 10485                                           0.863644
#
#        Nuclei_Texture_InverseDifferenceMoment_PM_3_03_256  \
# 10353                                          -0.031256
# 8571                                            0.151453
# 9725                                            0.900353
# 10594                                          -0.497792
# 69                                             -0.157421
# ...                                                  ...
# 7443                                           -0.330052
# 9763                                            0.515576
# 10640                                           0.898360
# 7475                                            0.279280
# 10485                                           0.839225
#
#        Nuclei_Texture_SumEntropy_PM_3_01_256  \
# 10353                               1.381606
# 8571                               -0.524604
# 9725                               -0.530664
# 10594                              -0.090549
# 69                                  0.209429
# ...                                      ...
# 7443                                1.411098
# 9763                               -0.429877
# 10640                              -0.648194
# 7475                                0.152091
# 10485                              -1.168766
#
#        Nuclei_Texture_SumVariance_ER_3_01_256  \
# 10353                                0.471091
# 8571                                -0.306646
# 9725                                -0.460011
# 10594                               -0.295706
# 69                                   0.219539
# ...                                       ...
# 7443                                 4.714502
# 9763                                -0.390364
# 10640                               -0.456984
# 7475                                -0.309532
# 10485                               -0.492971
#
#        Nuclei_Texture_SumVariance_Mitochondria_3_03_256  \
# 10353                                          1.593898
# 8571                                          -0.242326
# 9725                                          -0.538967
# 10594                                         -0.198665
# 69                                             0.045737
# ...                                                 ...
# 7443                                           4.552814
# 9763                                          -0.463289
# 10640                                         -0.539547
# 7475                                          -0.196923
# 10485                                         -0.569049
#
#       Nuclei_Texture_SumVariance_PM_3_01_256
# 10353                               0.240940
# 8571                               -0.385639
# 9725                               -0.400047
# 10594                              -0.279227
# 69                                 -0.272029
# ...                                      ...
# 7443                                0.805159
# 9763                               -0.395503
# 10640                              -0.373016
# 7475                                0.056296
# 10485                              -0.423535
#
# [1415 rows x 657 columns]},
#     'localhost240927060001': {   'orig_train_df':      Metadata_WellRow  Metadata_WellCol  Metadata_heart_number  \
# 8057                E                11                     19
# 6432                E                 5                     19
# 6443                E                 5                     19
# 7922                E                11                     19
# 7126                E                 8                     19
# ...               ...               ...                    ...
# 6406                E                 5                     19
# 7130                E                 8                     19
# 8175                E                11                     19
# 5730                E                 2                     19
# 6403                E                 5                     19
#
#      Metadata_cell_type Metadata_heart_failure_type Metadata_treatment  \
# 8057            failing      dilated_cardiomyopathy               DMSO
# 6432            failing      dilated_cardiomyopathy               DMSO
# 6443            failing      dilated_cardiomyopathy               DMSO
# 7922            failing      dilated_cardiomyopathy               DMSO
# 7126            failing      dilated_cardiomyopathy               DMSO
# ...                 ...                         ...                ...
# 6406            failing      dilated_cardiomyopathy               DMSO
# 7130            failing      dilated_cardiomyopathy               DMSO
# 8175            failing      dilated_cardiomyopathy               DMSO
# 5730            failing      dilated_cardiomyopathy               DMSO
# 6403            failing      dilated_cardiomyopathy               DMSO
#
#      Metadata_Pathway  Metadata_Nuclei_Location_Center_X  \
# 8057             None                         941.016767
# 6432             None                         801.903400
# 6443             None                         266.810162
# 7922             None                         393.859155
# 7126             None                         169.253855
# ...               ...                                ...
# 6406             None                         390.257206
# 7130             None                         396.414134
# 8175             None                         220.698826
# 5730             None                         366.675090
# 6403             None                         574.426578
#
#       Metadata_Nuclei_Location_Center_Y  Metadata_Cells_Location_Center_X  \
# 8057                         388.839705                        942.496880
# 6432                         357.867852                        814.586371
# 6443                         436.975300                        257.236841
# 7922                         435.044174                        396.403284
# 7126                         383.158956                        176.864149
# ...                                 ...                               ...
# 6406                         466.450850                        394.785143
# 7130                         369.415548                        360.831378
# 8175                         645.753956                        260.821365
# 5730                         623.008123                        393.107978
# 6403                         395.988704                        597.986015
#
#       ...  Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_01_256  \
# 8057  ...                                           0.227542
# 6432  ...                                          -0.864510
# 6443  ...                                          -1.008280
# 7922  ...                                           0.417578
# 7126  ...                                           0.605300
# ...   ...                                                ...
# 6406  ...                                          -0.757030
# 7130  ...                                           0.505191
# 8175  ...                                           1.123203
# 5730  ...                                           0.171734
# 6403  ...                                           0.983688
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_00_256  \
# 8057                                           2.046828
# 6432                                           0.618391
# 6443                                          -0.272071
# 7922                                           0.528216
# 7126                                           1.009834
# ...                                                 ...
# 6406                                           0.574086
# 7130                                          -0.044201
# 8175                                           0.167042
# 5730                                           1.466575
# 6403                                          -0.151928
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_01_256  \
# 8057                                           1.188420
# 6432                                          -0.602856
# 6443                                          -0.581885
# 7922                                           0.955768
# 7126                                           0.476077
# ...                                                 ...
# 6406                                           0.892161
# 7130                                           0.119553
# 8175                                           0.392555
# 5730                                           1.370836
# 6403                                           0.946456
#
#      Nuclei_Texture_InverseDifferenceMoment_PM_3_02_256  \
# 8057                                           1.104758
# 6432                                          -0.956971
# 6443                                           0.064909
# 7922                                           0.712051
# 7126                                           0.410568
# ...                                                 ...
# 6406                                           0.651185
# 7130                                          -0.076334
# 8175                                           0.205097
# 5730                                           1.180855
# 6403                                          -0.652955
#
#      Nuclei_Texture_InverseDifferenceMoment_PM_3_03_256  \
# 8057                                           1.600931
# 6432                                          -0.696795
# 6443                                           0.973702
# 7922                                           0.602796
# 7126                                           0.995731
# ...                                                 ...
# 6406                                           0.561321
# 7130                                           0.638935
# 8175                                          -0.082868
# 5730                                           1.100033
# 6403                                          -1.150707
#
#       Nuclei_Texture_SumEntropy_ER_3_03_256  \
# 8057                              -0.687351
# 6432                               0.737938
# 6443                              -0.229416
# 7922                              -0.652919
# 7126                              -0.629945
# ...                                     ...
# 6406                              -0.064763
# 7130                              -0.540206
# 8175                              -0.369247
# 5730                              -1.152484
# 6403                              -0.446054
#
#       Nuclei_Texture_SumEntropy_PM_3_01_256  \
# 8057                              -1.291972
# 6432                               0.287487
# 6443                              -0.466000
# 7922                              -0.990052
# 7126                              -0.923533
# ...                                     ...
# 6406                              -1.013204
# 7130                              -0.858859
# 8175                              -0.017979
# 5730                              -0.568766
# 6403                               0.292219
#
#       Nuclei_Texture_SumVariance_ER_3_01_256  \
# 8057                               -0.422801
# 6432                                0.038211
# 6443                               -0.292796
# 7922                               -0.388930
# 7126                               -0.380771
# ...                                      ...
# 6406                               -0.337558
# 7130                               -0.398448
# 8175                                0.240009
# 5730                               -0.443552
# 6403                               -0.376557
#
#       Nuclei_Texture_SumVariance_Hoechst_3_03_256  \
# 8057                                    -0.288589
# 6432                                     0.105148
# 6443                                    -0.089992
# 7922                                    -0.376037
# 7126                                    -0.395651
# ...                                           ...
# 6406                                     0.095634
# 7130                                    -0.139916
# 8175                                    -0.511674
# 5730                                    -0.804040
# 6403                                    -0.392299
#
#      Nuclei_Texture_SumVariance_PM_3_03_256
# 8057                              -0.469356
# 6432                              -0.279022
# 6443                              -0.332991
# 7922                              -0.470764
# 7126                              -0.438340
# ...                                     ...
# 6406                              -0.380619
# 7130                              -0.381022
# 8175                              -0.101072
# 5730                              -0.376212
# 6403                              -0.325342
#
# [1068 rows x 652 columns]},
#     'localhost240927120001': {   'orig_train_df':      Metadata_WellRow  Metadata_WellCol  Metadata_heart_number  \
# 9                   B                 2                      7
# 5630                E                 2                     19
# 5391                E                 2                     19
# 5575                E                 2                     19
# 5424                E                 2                     19
# ...               ...               ...                    ...
# 5564                E                 2                     19
# 7327                E                 8                     19
# 6598                E                 5                     19
# 8137                E                11                     19
# 5398                E                 2                     19
#
#      Metadata_cell_type Metadata_heart_failure_type Metadata_treatment  \
# 9               healthy                        None               DMSO
# 5630            failing      dilated_cardiomyopathy               DMSO
# 5391            failing      dilated_cardiomyopathy               DMSO
# 5575            failing      dilated_cardiomyopathy               DMSO
# 5424            failing      dilated_cardiomyopathy               DMSO
# ...                 ...                         ...                ...
# 5564            failing      dilated_cardiomyopathy               DMSO
# 7327            failing      dilated_cardiomyopathy               DMSO
# 6598            failing      dilated_cardiomyopathy               DMSO
# 8137            failing      dilated_cardiomyopathy               DMSO
# 5398            failing      dilated_cardiomyopathy               DMSO
#
#      Metadata_Pathway  Metadata_Nuclei_Location_Center_X  \
# 9                None                         586.110856
# 5630             None                         544.012459
# 5391             None                         767.384844
# 5575             None                         937.835383
# 5424             None                         940.066440
# ...               ...                                ...
# 5564             None                         311.386183
# 7327             None                         648.431592
# 6598             None                         563.590376
# 8137             None                         857.616279
# 5398             None                          58.693632
#
#       Metadata_Nuclei_Location_Center_Y  Metadata_Cells_Location_Center_X  \
# 9                            272.986789                        585.812571
# 5630                        1015.857049                        540.169864
# 5391                         203.437593                        777.096195
# 5575                         725.915984                        892.558337
# 5424                         420.071550                        924.417976
# ...                                 ...                               ...
# 5564                         547.484145                        293.705569
# 7327                         320.191542                        678.015371
# 6598                         628.279457                        573.414488
# 8137                         818.590971                        858.046726
# 5398                         361.972461                         79.331313
#
#       ...  Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_02_256  \
# 9     ...                                           0.475354
# 5630  ...                                           0.131469
# 5391  ...                                          -0.860799
# 5575  ...                                          -1.298418
# 5424  ...                                          -0.638285
# ...   ...                                                ...
# 5564  ...                                           0.721577
# 7327  ...                                           1.124674
# 6598  ...                                           2.226648
# 8137  ...                                          -0.590986
# 5398  ...                                          -1.899178
#
#       Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_03_256  \
# 9                                             -0.150761
# 5630                                          -0.021095
# 5391                                          -1.486686
# 5575                                          -1.539258
# 5424                                          -0.809294
# ...                                                 ...
# 5564                                           1.069212
# 7327                                           1.417675
# 6598                                           2.325211
# 8137                                           0.278464
# 5398                                          -0.901824
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_00_256  \
# 9                                              0.592052
# 5630                                           0.464286
# 5391                                          -0.463749
# 5575                                           0.258823
# 5424                                           0.741930
# ...                                                 ...
# 5564                                           0.947202
# 7327                                          -3.284453
# 6598                                           2.681148
# 8137                                           1.501779
# 5398                                          -1.131216
#
#      Nuclei_Texture_InverseDifferenceMoment_PM_3_01_256  \
# 9                                              0.660238
# 5630                                           0.844515
# 5391                                           0.336024
# 5575                                           0.417707
# 5424                                           1.372527
# ...                                                 ...
# 5564                                           0.486920
# 7327                                          -2.701106
# 6598                                           2.875890
# 8137                                           0.645970
# 5398                                          -1.749364
#
#      Nuclei_Texture_InverseDifferenceMoment_PM_3_02_256  \
# 9                                              0.824522
# 5630                                           0.388414
# 5391                                          -0.436134
# 5575                                          -0.923615
# 5424                                           0.573394
# ...                                                 ...
# 5564                                           0.547081
# 7327                                          -3.678136
# 6598                                           2.669704
# 8137                                           0.657505
# 5398                                          -1.540961
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_03_256  \
# 9                                              0.602509
# 5630                                           0.188370
# 5391                                          -1.128984
# 5575                                          -1.161158
# 5424                                          -0.009191
# ...                                                 ...
# 5564                                           1.048690
# 7327                                          -3.268685
# 6598                                           2.782971
# 8137                                           1.098699
# 5398                                          -0.477910
#
#       Nuclei_Texture_SumEntropy_PM_3_01_256  \
# 9                                 -0.493653
# 5630                              -0.576802
# 5391                               0.109277
# 5575                               0.552393
# 5424                              -0.265120
# ...                                     ...
# 5564                              -0.625103
# 7327                               3.411080
# 6598                              -3.014997
# 8137                              -1.009499
# 5398                               1.026118
#
#       Nuclei_Texture_SumVariance_ER_3_01_256  \
# 9                                  -0.406518
# 5630                                0.120790
# 5391                               -0.129621
# 5575                                0.188197
# 5424                               -0.381262
# ...                                      ...
# 5564                               -0.449688
# 7327                                0.462324
# 6598                               -0.512114
# 8137                               -0.433993
# 5398                                0.801274
#
#       Nuclei_Texture_SumVariance_Mitochondria_3_03_256  \
# 9                                            -0.460192
# 5630                                         -0.154618
# 5391                                         -0.210098
# 5575                                          0.361900
# 5424                                         -0.376541
# ...                                                ...
# 5564                                         -0.416547
# 7327                                          0.635393
# 6598                                         -0.560883
# 8137                                         -0.215288
# 5398                                          2.742959
#
#      Nuclei_Texture_SumVariance_PM_3_01_256
# 9                                 -0.333301
# 5630                              -0.367815
# 5391                              -0.250391
# 5575                              -0.109440
# 5424                              -0.304168
# ...                                     ...
# 5564                              -0.346397
# 7327                               6.464765
# 6598                              -0.501134
# 8137                              -0.414071
# 5398                               0.153873
#
# [1059 rows x 684 columns]},
#     'localhost240928120001': {   'orig_train_df':      Metadata_WellRow  Metadata_WellCol  Metadata_heart_number  \
# 502                 B                 5                      7
# 901                 B                11                      7
# 6474                E                 5                     19
# 5647                E                 2                     19
# 7013                E                 8                     19
# ...               ...               ...                    ...
# 7842                E                11                     19
# 7051                E                 8                     19
# 17                  B                 2                      7
# 7784                E                11                     19
# 5639                E                 2                     19
#
#      Metadata_cell_type Metadata_heart_failure_type Metadata_treatment  \
# 502             healthy                        None               DMSO
# 901             healthy                        None               DMSO
# 6474            failing      dilated_cardiomyopathy               DMSO
# 5647            failing      dilated_cardiomyopathy               DMSO
# 7013            failing      dilated_cardiomyopathy               DMSO
# ...                 ...                         ...                ...
# 7842            failing      dilated_cardiomyopathy               DMSO
# 7051            failing      dilated_cardiomyopathy               DMSO
# 17              healthy                        None               DMSO
# 7784            failing      dilated_cardiomyopathy               DMSO
# 5639            failing      dilated_cardiomyopathy               DMSO
#
#      Metadata_Pathway  Metadata_Nuclei_Location_Center_X  \
# 502              None                         732.329564
# 901              None                         680.117492
# 6474             None                         213.315677
# 5647             None                         702.332976
# 7013             None                         685.934183
# ...               ...                                ...
# 7842             None                         409.042197
# 7051             None                         321.806011
# 17               None                         685.270423
# 7784             None                         454.064429
# 5639             None                         863.880618
#
#       Metadata_Nuclei_Location_Center_Y  Metadata_Cells_Location_Center_X  \
# 502                          637.749596                        742.335310
# 901                          506.400948                        647.661688
# 6474                         720.434857                        173.565045
# 5647                         590.523555                        709.683668
# 7013                         288.863411                        682.979201
# ...                                 ...                               ...
# 7842                         580.830636                        426.745510
# 7051                         265.892077                        330.041044
# 17                           390.511268                        668.010707
# 7784                         334.191121                        430.527486
# 5639                         506.903792                        856.391075
#
#       ...  Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_00_256  \
# 502   ...                                           0.429575
# 901   ...                                          -0.044193
# 6474  ...                                          -0.224319
# 5647  ...                                           0.769520
# 7013  ...                                           0.037086
# ...   ...                                                ...
# 7842  ...                                           0.097296
# 7051  ...                                           0.999839
# 17    ...                                           0.097668
# 7784  ...                                          -0.739789
# 5639  ...                                          -1.568565
#
#       Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_02_256  \
# 502                                            0.899489
# 901                                           -2.272272
# 6474                                           0.271063
# 5647                                           0.679121
# 7013                                          -0.417929
# ...                                                 ...
# 7842                                           0.330923
# 7051                                           0.345337
# 17                                            -0.056328
# 7784                                          -0.833906
# 5639                                          -0.462143
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_00_256  \
# 502                                           -0.131039
# 901                                           -1.199967
# 6474                                           0.256005
# 5647                                           0.809763
# 7013                                           0.469879
# ...                                                 ...
# 7842                                           0.483662
# 7051                                           1.466956
# 17                                             0.417558
# 7784                                           0.614594
# 5639                                          -1.437655
#
#      Nuclei_Texture_InverseDifferenceMoment_PM_3_01_256  \
# 502                                           -0.411480
# 901                                           -2.835579
# 6474                                           0.472862
# 5647                                           0.431955
# 7013                                           0.122834
# ...                                                 ...
# 7842                                           0.700329
# 7051                                           1.023356
# 17                                             0.197429
# 7784                                           0.643339
# 5639                                          -0.744892
#
#      Nuclei_Texture_InverseDifferenceMoment_PM_3_02_256  \
# 502                                           -0.431615
# 901                                           -3.170418
# 6474                                           0.497159
# 5647                                           0.443140
# 7013                                          -0.040159
# ...                                                 ...
# 7842                                           0.600568
# 7051                                           0.818578
# 17                                            -0.055281
# 7784                                           0.207607
# 5639                                           0.102014
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_03_256  \
# 502                                           -0.172730
# 901                                           -2.540800
# 6474                                           0.291646
# 5647                                           0.372898
# 7013                                           0.083674
# ...                                                 ...
# 7842                                           0.460130
# 7051                                           0.999278
# 17                                            -0.259720
# 7784                                           0.215320
# 5639                                          -1.047995
#
#       Nuclei_Texture_SumEntropy_ER_3_01_256  \
# 502                                0.143204
# 901                                3.249805
# 6474                              -0.749163
# 5647                              -0.705174
# 7013                              -0.109656
# ...                                     ...
# 7842                              -0.297147
# 7051                              -1.063946
# 17                                -0.921094
# 7784                               0.754168
# 5639                              -0.000643
#
#       Nuclei_Texture_SumEntropy_PM_3_01_256  \
# 502                                0.148588
# 901                                3.131297
# 6474                               0.102065
# 5647                              -0.597468
# 7013                              -0.204877
# ...                                     ...
# 7842                              -0.360177
# 7051                              -1.241845
# 17                                 0.045218
# 7784                               0.312381
# 5639                               0.780569
#
#       Nuclei_Texture_SumVariance_ER_3_03_256  \
# 502                                -0.245556
# 901                                 5.094638
# 6474                               -0.360170
# 5647                               -0.357599
# 7013                               -0.233049
# ...                                      ...
# 7842                               -0.323511
# 7051                               -0.389647
# 17                                 -0.342956
# 7784                               -0.110742
# 5639                               -0.283256
#
#      Nuclei_Texture_SumVariance_PM_3_03_256
# 502                               -0.264352
# 901                                4.593341
# 6474                              -0.177204
# 5647                              -0.382856
# 7013                              -0.083203
# ...                                     ...
# 7842                              -0.362388
# 7051                              -0.427497
# 17                                -0.284654
# 7784                              -0.208199
# 5639                              -0.107855
#
# [1101 rows x 641 columns]}}

# %% [markdown]
# ## Perform downsampling on training data and output as data frame

# %%
# for loop to process each dataframe in the dict
for plate, info in training_data_dfs_dict.items():
    # load in training plate 4 data as downsampled to lowest class
    downsample_df = downsample_data(data=info["orig_train_df"], label=label)

    # Store the downsampled dataframe under 'downsample_train_df'
    training_data_dfs_dict[plate]["downsample_train_df"] = downsample_df

    # Export sample indices used in training the model to a new one-column CSV file
    output_file = f"{training_indices_dir}/{plate}_training_data_indices.csv"
    pd.DataFrame(downsample_df.index, columns=["Index"]).to_csv(
        output_file, index=False
    )

    print(f"CSV file created at {output_file} with {len(downsample_df.index)} entries.")

    print(downsample_df.shape)
    print(downsample_df["Metadata_cell_type"].value_counts())
# Out:
# CSV file created at training_indices/localhost240927120001_training_data_indices.csv with 536 entries.
# (536, 684)
# failing    268
# healthy    268
# Name: Metadata_cell_type, dtype: int64
# CSV file created at training_indices/localhost240928120001_training_data_indices.csv with 572 entries.
# (572, 641)
# failing    286
# healthy    286
# Name: Metadata_cell_type, dtype: int64
# CSV file created at training_indices/combined_batch1_training_data_indices.csv with 4816 entries.
# (4816, 494)
# failing    2408
# healthy    2408
# Name: Metadata_cell_type, dtype: int64
# CSV file created at training_indices/localhost240926150001_training_data_indices.csv with 878 entries.
# (878, 657)
# failing    439
# healthy    439
# Name: Metadata_cell_type, dtype: int64
# CSV file created at training_indices/localhost240927060001_training_data_indices.csv with 422 entries.
# (422, 652)
# failing    211
# healthy    211
# Name: Metadata_cell_type, dtype: int64

# %% [markdown]
# ## Get X and y data and label encoder for final and shuffled models for all plates

# %%
# Encode classes
le = LabelEncoder()

for plate, info in training_data_dfs_dict.items():
    # Get downsampled dataframe
    downsample_df = info["downsample_train_df"]

    # Get not shuffled training data from downsampled df (e.g., "final")
    X_train, y_train = get_X_y_data(df=downsample_df, label=label, shuffle=False)

    # Print out the number of features the model will train on per plate
    print(f"Number of features for plate {plate}: {X_train.shape[1]}")

    # Fit the LabelEncoder on the non-shuffled labels
    le.fit(y_train)

    # Encode the labels for both non-shuffled data
    y_train_encoded = le.transform(y_train)

    # Get shuffled training data from downsampled df(e.g., "shuffled_baseline")
    X_shuffled_train, y_shuffled_train = get_X_y_data(
        df=downsample_df, label=label, shuffle=True
    )

    # Encode the labels for the shuffled labels
    y_shuffled_train_encoded = le.transform(y_shuffled_train)

    # Store the X and y data under respective keys
    training_data_dfs_dict[plate]["X_train"] = X_train
    training_data_dfs_dict[plate]["y_train"] = y_train
    training_data_dfs_dict[plate]["X_shuffled_train"] = X_shuffled_train
    training_data_dfs_dict[plate]["y_shuffled_train"] = y_shuffled_train_encoded

    # Save label encoder
    dump(le, f"{encoder_dir}/label_encoder_{plate}.joblib")

# Print the class mapping to see the encoding
class_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print("Class Mapping:")
print(class_mapping)
# Out:
# Number of features for plate localhost240927120001: 664
# Number of features for plate localhost240928120001: 621
# Number of features for plate combined_batch1: 474
# Number of features for plate localhost240926150001: 637
# Number of features for plate localhost240927060001: 632
# Class Mapping:
# {'failing': 0, 'healthy': 1}

# %% [markdown]
# ## Train the models
#
# These hyperparameters are set based on the model training from the [`cellpainting_predicts_cardiac_fibrosis` repository](https://github.com/WayScience/cellpainting_predicts_cardiac_fibrosis).
# The following model training code is derived from the [model training notebook](https://github.com/WayScience/cellpainting_predicts_cardiac_fibrosis/blob/main/5.machine_learning/0.train_logistic_regression/1.train_models.ipynb).
# We will be using RandomizedSearchCV to hyperparameterize the model since that is how the original model was trained and we want to remain consistent.

# %% [markdown]
# ### Set up the model and hyper parameter method

# %%
# Set folds for k-fold cross validation (default is 5)
straified_k_folds = StratifiedKFold(n_splits=10, shuffle=False)

# Set Logistic Regression model parameters (use default for max_iter)
logreg_params = {
    "penalty": "elasticnet",
    "solver": "saga",
    "max_iter": 1000,
    "n_jobs": -1,
    "random_state": 0,
    "class_weight": "balanced",
}

# Define the hyperparameter search space for RandomizedSearchCV
param_dist = {
    "C": np.logspace(-3, 3, 7),
    "l1_ratio": np.linspace(0, 1, 11),
}

# Set the random search hyperparameterization method parameters (used default for "cv" and "n_iter" parameter)
random_search_params = {
    "param_distributions": param_dist,
    "scoring": "f1_weighted",
    "random_state": 0,
    "n_jobs": -1,
    "cv": straified_k_folds,
}

# %% [markdown]
# ### Train final and shuffled models per plate and combined batch

# %%
# Initialize Logistic Regression and RandomizedSearchCV
logreg = LogisticRegression(**logreg_params)
random_search = RandomizedSearchCV(logreg, **random_search_params)

# Loop through the training data dictionary for both non-shuffled and shuffled data
for plate, info in training_data_dfs_dict.items():
    # Get the non-shuffled and shuffled data for the current feature type
    X_train = info["X_train"]
    y_train = info["y_train"]
    X_shuffled_train = info["X_shuffled_train"]
    y_shuffled_train = info["y_shuffled_train"]

    # Prevent the convergence warning in sklearn, it does not impact the result
    with parallel_backend("multiprocessing"):
        with warnings.catch_warnings():
            warnings.filterwarnings(
                "ignore", category=ConvergenceWarning, module="sklearn"
            )
            ########################################################
            # Train the model for non-shuffled (final) training data
            ########################################################
            print(f"Training model for {plate} features (final)...")
            final_random_search = clone(random_search)
            final_random_search.fit(X_train, y_train)
            print(
                f"Optimal parameters for {plate} features (final):",
                final_random_search.best_params_,
            )

            # Save the model for non-shuffled/final data using joblib
            final_model_filename = model_dir / f"{plate}_final_downsample.joblib"
            dump(final_random_search.best_estimator_, final_model_filename)
            print(f"Model saved as: {final_model_filename}")

            ########################################################
            # Train the model for shuffled training data
            ########################################################
            print(f"Training model for {plate} features (shuffled)...")
            shuffled_random_search = clone(random_search)
            shuffled_random_search.fit(X_shuffled_train, y_shuffled_train)
            print(
                f"Optimal parameters for {plate} features (shuffled):",
                shuffled_random_search.best_params_,
            )

            # Save the final model for shuffled data using joblib
            shuffled_final_model_filename = (
                model_dir / f"{plate}_shuffled_downsample.joblib"
            )
            dump(shuffled_random_search.best_estimator_, shuffled_final_model_filename)
            print(f"Model saved as: {shuffled_final_model_filename}")
# Out:
# Training model for localhost240927120001 features (final)...
# Optimal parameters for localhost240927120001 features (final): {'l1_ratio': 0.4, 'C': 0.1}
# Model saved as: models/localhost240927120001_final_downsample.joblib
# Training model for localhost240927120001 features (shuffled)...
# Optimal parameters for localhost240927120001 features (shuffled): {'l1_ratio': 0.4, 'C': 10.0}
# Model saved as: models/localhost240927120001_shuffled_downsample.joblib
# Training model for localhost240928120001 features (final)...
# Optimal parameters for localhost240928120001 features (final): {'l1_ratio': 0.4, 'C': 0.1}
# Model saved as: models/localhost240928120001_final_downsample.joblib
# Training model for localhost240928120001 features (shuffled)...
# Optimal parameters for localhost240928120001 features (shuffled): {'l1_ratio': 0.4, 'C': 0.1}
# Model saved as: models/localhost240928120001_shuffled_downsample.joblib
# Training model for combined_batch1 features (final)...
# Optimal parameters for combined_batch1 features (final): {'l1_ratio': 0.4, 'C': 10.0}
# Model saved as: models/combined_batch1_final_downsample.joblib
# Training model for combined_batch1 features (shuffled)...
# Optimal parameters for combined_batch1 features (shuffled): {'l1_ratio': 0.4, 'C': 0.1}
# Model saved as: models/combined_batch1_shuffled_downsample.joblib
# Training model for localhost240926150001 features (final)...
# Optimal parameters for localhost240926150001 features (final): {'l1_ratio': 0.4, 'C': 10.0}
# Model saved as: models/localhost240926150001_final_downsample.joblib
# Training model for localhost240926150001 features (shuffled)...
# Optimal parameters for localhost240926150001 features (shuffled): {'l1_ratio': 1.0, 'C': 10.0}
# Model saved as: models/localhost240926150001_shuffled_downsample.joblib
# Training model for localhost240927060001 features (final)...
# Optimal parameters for localhost240927060001 features (final): {'l1_ratio': 0.4, 'C': 0.1}
# Model saved as: models/localhost240927060001_final_downsample.joblib
# Training model for localhost240927060001 features (shuffled)...
# Optimal parameters for localhost240927060001 features (shuffled): {'l1_ratio': 0.2, 'C': 1000.0}
# Model saved as: models/localhost240927060001_shuffled_downsample.joblib
