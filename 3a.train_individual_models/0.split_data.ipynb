# %% [markdown]
# # Split each plate from the batch data into training, testing, and holdout data

# %%
import pathlib
import random

import pprint

import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Set paths and variables

# %%
# Set random state for the whole notebook to ensure reproducibility
random.seed(0)

# Path to directory with feature selected profiles
path_to_feature_selected_data = pathlib.Path(
    "../3.preprocessing_features/data/single_cell_profiles/"
).resolve(strict=True)

# Find all feature selected parquet files
feature_selected_files = list(path_to_feature_selected_data.glob("*_feature_selected.parquet"))

# Make directory for split data
output_dir = pathlib.Path("./data")
output_dir.mkdir(exist_ok=True)

# %% [markdown]
# ## Load in feature selected data

# %%
# Load in all feature selected files as dataframes
feature_selected_dfs_dict = {
    pathlib.Path(file).stem.split('_')[0]: pd.read_parquet(file) for file in feature_selected_files
}

pprint.pprint(feature_selected_dfs_dict, indent=4)
# Out:
# {   'localhost240926150001':       Metadata_WellRow  Metadata_WellCol  Metadata_heart_number  \
# 0                    B                 2                      7
# 1                    B                 2                      7
# 2                    B                 2                      7
# 3                    B                 2                      7
# 4                    B                 2                      7
# ...                ...               ...                    ...
# 16561                G                11                     19
# 16562                G                11                     19
# 16563                G                11                     19
# 16564                G                11                     19
# 16565                G                11                     19
#
#       Metadata_cell_type Metadata_heart_failure_type Metadata_treatment  \
# 0                healthy                        None               DMSO
# 1                healthy                        None               DMSO
# 2                healthy                        None               DMSO
# 3                healthy                        None               DMSO
# 4                healthy                        None               DMSO
# ...                  ...                         ...                ...
# 16561            failing      dilated_cardiomyopathy        UCD-0001842
# 16562            failing      dilated_cardiomyopathy        UCD-0001842
# 16563            failing      dilated_cardiomyopathy        UCD-0001842
# 16564            failing      dilated_cardiomyopathy        UCD-0001842
# 16565            failing      dilated_cardiomyopathy        UCD-0001842
#
#          Metadata_Pathway  Metadata_Nuclei_Location_Center_X  \
# 0                    None                         980.256203
# 1                    None                         753.136818
# 2                    None                         715.905046
# 3                    None                         775.245379
# 4                    None                         480.767918
# ...                   ...                                ...
# 16561  Neuronal Signaling                         470.533292
# 16562  Neuronal Signaling                         195.801569
# 16563  Neuronal Signaling                         175.141247
# 16564  Neuronal Signaling                         270.661935
# 16565  Neuronal Signaling                         195.251529
#
#        Metadata_Nuclei_Location_Center_Y  Metadata_Cells_Location_Center_X  \
# 0                              77.211974                        995.747159
# 1                             109.791699                        817.073428
# 2                             128.905710                        720.002556
# 3                             177.171447                        795.615332
# 4                              86.273038                        516.485273
# ...                                  ...                               ...
# 16561                         779.533292                        469.640241
# 16562                         807.465098                        197.599655
# 16563                         871.574756                        175.964692
# 16564                         882.210831                        295.782061
# 16565                         917.496942                        201.716318
#
#        ...  Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_01_256  \
# 0      ...                                          -0.063315
# 1      ...                                          -0.087274
# 2      ...                                           0.446102
# 3      ...                                          -0.272272
# 4      ...                                          -1.054008
# ...    ...                                                ...
# 16561  ...                                           2.025540
# 16562  ...                                           1.135593
# 16563  ...                                          -0.567855
# 16564  ...                                           1.726037
# 16565  ...                                           0.047248
#
#        Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_03_256  \
# 0                                               0.029853
# 1                                              -0.553605
# 2                                               0.527982
# 3                                              -0.269428
# 4                                              -0.394548
# ...                                                  ...
# 16561                                           2.414727
# 16562                                           1.385918
# 16563                                          -0.638212
# 16564                                           1.978031
# 16565                                           0.113295
#
#        Nuclei_Texture_InverseDifferenceMoment_PM_3_00_256  \
# 0                                               0.153982
# 1                                               0.256129
# 2                                               0.649873
# 3                                               0.189097
# 4                                              -0.204173
# ...                                                  ...
# 16561                                           0.913639
# 16562                                           0.203726
# 16563                                          -1.089732
# 16564                                           1.115128
# 16565                                          -1.451705
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_01_256  \
# 0                                               0.321023
# 1                                               0.010533
# 2                                               0.760709
# 3                                              -0.193065
# 4                                              -0.603043
# ...                                                  ...
# 16561                                           1.092188
# 16562                                           0.043727
# 16563                                          -1.352721
# 16564                                           0.691631
# 16565                                          -1.638173
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_02_256  \
# 0                                               0.163817
# 1                                               0.087143
# 2                                               0.640535
# 3                                               0.126604
# 4                                              -0.607941
# ...                                                  ...
# 16561                                           0.953722
# 16562                                           0.319827
# 16563                                          -2.211409
# 16564                                           0.447620
# 16565                                          -2.042154
#
#        Nuclei_Texture_InverseDifferenceMoment_PM_3_03_256  \
# 0                                               0.306940
# 1                                               0.197116
# 2                                               0.662559
# 3                                               0.457620
# 4                                              -0.602644
# ...                                                  ...
# 16561                                           1.103699
# 16562                                          -0.065365
# 16563                                          -2.352072
# 16564                                           0.997470
# 16565                                          -1.676527
#
#        Nuclei_Texture_SumEntropy_PM_3_01_256  \
# 0                                  -0.361039
# 1                                  -0.544839
# 2                                  -0.757203
# 3                                  -0.025333
# 4                                   0.739263
# ...                                      ...
# 16561                              -1.258961
# 16562                              -0.314916
# 16563                               1.481672
# 16564                              -0.447808
# 16565                               0.979745
#
#        Nuclei_Texture_SumVariance_ER_3_01_256  \
# 0                                   -0.385753
# 1                                   -0.160853
# 2                                   -0.433685
# 3                                   -0.097371
# 4                                   -0.169450
# ...                                       ...
# 16561                               -0.426718
# 16562                               -0.339563
# 16563                                0.427795
# 16564                               -0.216096
# 16565                                0.401662
#
#        Nuclei_Texture_SumVariance_Mitochondria_3_03_256  \
# 0                                             -0.318552
# 1                                             -0.347299
# 2                                             -0.559468
# 3                                             -0.306275
# 4                                              0.108724
# ...                                                 ...
# 16561                                         -0.602995
# 16562                                         -0.586732
# 16563                                         -0.382738
# 16564                                         -0.606831
# 16565                                         -0.545229
#
#       Nuclei_Texture_SumVariance_PM_3_01_256
# 0                                  -0.378396
# 1                                  -0.411975
# 2                                  -0.429483
# 3                                  -0.318309
# 4                                  -0.104884
# ...                                      ...
# 16561                              -0.465389
# 16562                              -0.350658
# 16563                               0.390745
# 16564                              -0.343121
# 16565                               0.026141
#
# [16566 rows x 657 columns],
#     'localhost240927060001':       Metadata_WellRow  Metadata_WellCol  Metadata_heart_number  \
# 0                    B                 2                      7
# 1                    B                 2                      7
# 2                    B                 2                      7
# 3                    B                 2                      7
# 4                    B                 2                      7
# ...                ...               ...                    ...
# 12392                G                11                     19
# 12393                G                11                     19
# 12394                G                11                     19
# 12395                G                11                     19
# 12396                G                11                     19
#
#       Metadata_cell_type Metadata_heart_failure_type Metadata_treatment  \
# 0                healthy                        None               DMSO
# 1                healthy                        None               DMSO
# 2                healthy                        None               DMSO
# 3                healthy                        None               DMSO
# 4                healthy                        None               DMSO
# ...                  ...                         ...                ...
# 12392            failing      dilated_cardiomyopathy        UCD-0001842
# 12393            failing      dilated_cardiomyopathy        UCD-0001842
# 12394            failing      dilated_cardiomyopathy        UCD-0001842
# 12395            failing      dilated_cardiomyopathy        UCD-0001842
# 12396            failing      dilated_cardiomyopathy        UCD-0001842
#
#          Metadata_Pathway  Metadata_Nuclei_Location_Center_X  \
# 0                    None                         870.048176
# 1                    None                         372.665138
# 2                    None                         691.469799
# 3                    None                         658.817385
# 4                    None                        1031.773316
# ...                   ...                                ...
# 12392  Neuronal Signaling                         256.007765
# 12393  Neuronal Signaling                         303.415013
# 12394  Neuronal Signaling                         197.660737
# 12395  Neuronal Signaling                         505.089268
# 12396  Neuronal Signaling                         282.473038
#
#        Metadata_Nuclei_Location_Center_Y  Metadata_Cells_Location_Center_X  \
# 0                             222.975912                        883.760337
# 1                              78.150612                        422.940605
# 2                             396.812081                        683.988473
# 3                             176.364500                        656.476395
# 4                              87.448834                       1023.158705
# ...                                  ...                               ...
# 12392                         765.603969                        232.626407
# 12393                         784.643658                        318.955966
# 12394                         833.390089                        188.161109
# 12395                         868.344534                        497.382580
# 12396                         962.857338                        290.565731
#
#        ...  Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_01_256  \
# 0      ...                                          -0.471414
# 1      ...                                           0.033352
# 2      ...                                           0.305987
# 3      ...                                          -1.502350
# 4      ...                                          -0.555790
# ...    ...                                                ...
# 12392  ...                                          -0.547836
# 12393  ...                                          -0.780613
# 12394  ...                                           0.511209
# 12395  ...                                           0.908913
# 12396  ...                                          -0.479326
#
#        Nuclei_Texture_InverseDifferenceMoment_PM_3_00_256  \
# 0                                              -0.028467
# 1                                              -0.674620
# 2                                               0.204027
# 3                                              -0.856654
# 4                                              -2.088097
# ...                                                  ...
# 12392                                          -0.014887
# 12393                                          -0.753928
# 12394                                           0.357790
# 12395                                           0.905600
# 12396                                           0.333513
#
#        Nuclei_Texture_InverseDifferenceMoment_PM_3_01_256  \
# 0                                               0.025132
# 1                                              -0.054664
# 2                                               0.415166
# 3                                              -0.524341
# 4                                              -0.929627
# ...                                                  ...
# 12392                                           0.065703
# 12393                                          -0.492360
# 12394                                           0.572502
# 12395                                           1.162441
# 12396                                           0.454373
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_02_256  \
# 0                                               0.531559
# 1                                              -0.974624
# 2                                               0.695386
# 3                                              -0.361560
# 4                                              -2.144620
# ...                                                  ...
# 12392                                           0.289404
# 12393                                          -0.201774
# 12394                                           0.773780
# 12395                                           1.230343
# 12396                                           0.449465
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_03_256  \
# 0                                               0.161083
# 1                                              -1.157279
# 2                                               0.509317
# 3                                               0.095980
# 4                                              -2.443222
# ...                                                  ...
# 12392                                           0.213318
# 12393                                          -0.705679
# 12394                                           0.547234
# 12395                                           1.110513
# 12396                                           0.758971
#
#        Nuclei_Texture_SumEntropy_ER_3_03_256  \
# 0                                   0.495831
# 1                                   1.315214
# 2                                  -0.121268
# 3                                   0.521777
# 4                                   2.376656
# ...                                      ...
# 12392                               0.229003
# 12393                               0.923091
# 12394                              -0.086772
# 12395                              -0.557044
# 12396                               0.292488
#
#        Nuclei_Texture_SumEntropy_PM_3_01_256  \
# 0                                  -0.084311
# 1                                   1.004183
# 2                                  -0.669122
# 3                                  -0.099079
# 4                                   1.224159
# ...                                      ...
# 12392                              -0.290292
# 12393                               0.268932
# 12394                              -0.630081
# 12395                              -0.866066
# 12396                              -0.584107
#
#        Nuclei_Texture_SumVariance_ER_3_01_256  \
# 0                                    0.072375
# 1                                    1.256866
# 2                                   -0.338770
# 3                                   -0.114857
# 4                                    2.356945
# ...                                       ...
# 12392                               -0.090625
# 12393                                0.011396
# 12394                               -0.303984
# 12395                               -0.342022
# 12396                                0.055567
#
#        Nuclei_Texture_SumVariance_Hoechst_3_03_256  \
# 0                                         0.006424
# 1                                         0.384265
# 2                                        -0.789392
# 3                                        -0.000569
# 4                                         1.308259
# ...                                            ...
# 12392                                     0.753970
# 12393                                     1.366307
# 12394                                    -0.300438
# 12395                                    -0.725346
# 12396                                    -0.118464
#
#       Nuclei_Texture_SumVariance_PM_3_03_256
# 0                                  -0.267915
# 1                                  -0.009370
# 2                                  -0.357217
# 3                                  -0.250174
# 4                                   0.057235
# ...                                      ...
# 12392                              -0.340795
# 12393                              -0.256176
# 12394                              -0.417056
# 12395                              -0.403514
# 12396                              -0.404075
#
# [12397 rows x 652 columns],
#     'localhost240927120001':       Metadata_WellRow  Metadata_WellCol  Metadata_heart_number  \
# 0                    B                 2                      7
# 1                    B                 2                      7
# 2                    B                 2                      7
# 3                    B                 2                      7
# 4                    B                 2                      7
# ...                ...               ...                    ...
# 12897                G                11                     19
# 12898                G                11                     19
# 12899                G                11                     19
# 12900                G                11                     19
# 12901                G                11                     19
#
#       Metadata_cell_type Metadata_heart_failure_type Metadata_treatment  \
# 0                healthy                        None               DMSO
# 1                healthy                        None               DMSO
# 2                healthy                        None               DMSO
# 3                healthy                        None               DMSO
# 4                healthy                        None               DMSO
# ...                  ...                         ...                ...
# 12897            failing      dilated_cardiomyopathy        UCD-0001842
# 12898            failing      dilated_cardiomyopathy        UCD-0001842
# 12899            failing      dilated_cardiomyopathy        UCD-0001842
# 12900            failing      dilated_cardiomyopathy        UCD-0001842
# 12901            failing      dilated_cardiomyopathy        UCD-0001842
#
#          Metadata_Pathway  Metadata_Nuclei_Location_Center_X  \
# 0                    None                         907.921642
# 1                    None                         396.033681
# 2                    None                         139.872166
# 3                    None                          67.083920
# 4                    None                         423.904883
# ...                   ...                                ...
# 12897  Neuronal Signaling                        1009.022496
# 12898  Neuronal Signaling                         827.189333
# 12899  Neuronal Signaling                         514.638889
# 12900  Neuronal Signaling                         566.228283
# 12901  Neuronal Signaling                         372.389056
#
#        Metadata_Nuclei_Location_Center_Y  Metadata_Cells_Location_Center_X  \
# 0                              66.684968                        848.242523
# 1                              82.690457                        348.336337
# 2                             164.719773                        139.436766
# 3                             255.277582                        100.856233
# 4                             318.767914                        455.160276
# ...                                  ...                               ...
# 12897                         735.360471                       1023.531245
# 12898                         974.754000                        843.360354
# 12899                         768.695688                        473.646885
# 12900                         875.665657                        615.205422
# 12901                         896.647023                        361.693088
#
#        ...  Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_02_256  \
# 0      ...                                          -0.592359
# 1      ...                                          -0.191731
# 2      ...                                           0.254576
# 3      ...                                           0.272540
# 4      ...                                           0.163590
# ...    ...                                                ...
# 12897  ...                                           1.167222
# 12898  ...                                           0.063698
# 12899  ...                                          -0.086901
# 12900  ...                                           0.352060
# 12901  ...                                           0.029519
#
#        Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_03_256  \
# 0                                              -0.893847
# 1                                              -0.387954
# 2                                               0.407777
# 3                                              -0.498367
# 4                                              -0.031121
# ...                                                  ...
# 12897                                           0.688000
# 12898                                          -0.228176
# 12899                                          -0.067288
# 12900                                           0.459135
# 12901                                           0.026896
#
#        Nuclei_Texture_InverseDifferenceMoment_PM_3_00_256  \
# 0                                               0.327355
# 1                                              -0.795001
# 2                                              -0.662577
# 3                                              -0.134474
# 4                                              -0.413584
# ...                                                  ...
# 12897                                           1.742341
# 12898                                           0.558276
# 12899                                           0.480455
# 12900                                          -0.615104
# 12901                                           0.517780
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_01_256  \
# 0                                               0.489503
# 1                                              -0.903883
# 2                                              -1.573804
# 3                                              -0.245251
# 4                                              -0.144234
# ...                                                  ...
# 12897                                           1.754561
# 12898                                           0.582644
# 12899                                           0.762543
# 12900                                          -1.052215
# 12901                                           0.533079
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_02_256  \
# 0                                               0.326130
# 1                                              -0.944581
# 2                                              -1.159428
# 3                                               0.205592
# 4                                              -0.089905
# ...                                                  ...
# 12897                                           1.827955
# 12898                                          -0.121448
# 12899                                           0.466338
# 12900                                          -1.266819
# 12901                                           0.347975
#
#        Nuclei_Texture_InverseDifferenceMoment_PM_3_03_256  \
# 0                                               0.012874
# 1                                              -0.987366
# 2                                              -0.080352
# 3                                              -0.218538
# 4                                              -0.176026
# ...                                                  ...
# 12897                                           1.843189
# 12898                                           0.010617
# 12899                                           0.551220
# 12900                                          -1.088108
# 12901                                           0.357327
#
#        Nuclei_Texture_SumEntropy_PM_3_01_256  \
# 0                                   0.543994
# 1                                   0.824843
# 2                                   0.692844
# 3                                   0.148897
# 4                                   0.174056
# ...                                      ...
# 12897                              -1.511111
# 12898                              -0.272462
# 12899                              -0.646173
# 12900                               2.443226
# 12901                              -0.489901
#
#        Nuclei_Texture_SumVariance_ER_3_01_256  \
# 0                                   -0.270493
# 1                                   -0.370290
# 2                                   -0.084837
# 3                                   -0.112963
# 4                                   -0.180719
# ...                                       ...
# 12897                               -0.389355
# 12898                               -0.288071
# 12899                               -0.273508
# 12900                                3.809186
# 12901                               -0.334098
#
#        Nuclei_Texture_SumVariance_Mitochondria_3_03_256  \
# 0                                             -0.051838
# 1                                             -0.442164
# 2                                             -0.405587
# 3                                             -0.328375
# 4                                             -0.451139
# ...                                                 ...
# 12897                                         -0.460710
# 12898                                         -0.422461
# 12899                                         -0.446840
# 12900                                          6.961084
# 12901                                         -0.400022
#
#       Nuclei_Texture_SumVariance_PM_3_01_256
# 0                                  -0.138941
# 1                                   0.320484
# 2                                  -0.073081
# 3                                  -0.230012
# 4                                  -0.240370
# ...                                      ...
# 12897                              -0.448850
# 12898                              -0.327233
# 12899                              -0.313500
# 12900                               6.733423
# 12901                              -0.343179
#
# [12902 rows x 684 columns],
#     'localhost240928120001':       Metadata_WellRow  Metadata_WellCol  Metadata_heart_number  \
# 0                    B                 2                      7
# 1                    B                 2                      7
# 2                    B                 2                      7
# 3                    B                 2                      7
# 4                    B                 2                      7
# ...                ...               ...                    ...
# 12740                G                11                     19
# 12741                G                11                     19
# 12742                G                11                     19
# 12743                G                11                     19
# 12744                G                11                     19
#
#       Metadata_cell_type Metadata_heart_failure_type Metadata_treatment  \
# 0                healthy                        None               DMSO
# 1                healthy                        None               DMSO
# 2                healthy                        None               DMSO
# 3                healthy                        None               DMSO
# 4                healthy                        None               DMSO
# ...                  ...                         ...                ...
# 12740            failing      dilated_cardiomyopathy        UCD-0001842
# 12741            failing      dilated_cardiomyopathy        UCD-0001842
# 12742            failing      dilated_cardiomyopathy        UCD-0001842
# 12743            failing      dilated_cardiomyopathy        UCD-0001842
# 12744            failing      dilated_cardiomyopathy        UCD-0001842
#
#          Metadata_Pathway  Metadata_Nuclei_Location_Center_X  \
# 0                    None                         855.599578
# 1                    None                         613.937003
# 2                    None                         916.379710
# 3                    None                         530.411492
# 4                    None                         958.301695
# ...                   ...                                ...
# 12740  Neuronal Signaling                         844.483523
# 12741  Neuronal Signaling                         624.607674
# 12742  Neuronal Signaling                         465.851687
# 12743  Neuronal Signaling                         772.461146
# 12744  Neuronal Signaling                         547.915737
#
#        Metadata_Nuclei_Location_Center_Y  Metadata_Cells_Location_Center_X  \
# 0                             277.977481                        809.932735
# 1                             209.544343                        640.790427
# 2                             280.023188                        927.500461
# 3                              80.037145                        515.843583
# 4                              69.265085                        955.244723
# ...                                  ...                               ...
# 12740                         878.006250                        863.114131
# 12741                         946.718465                        620.027955
# 12742                         873.584341                        503.685592
# 12743                         975.338060                        757.283893
# 12744                         984.429129                        558.392859
#
#        ...  Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_00_256  \
# 0      ...                                          -0.169927
# 1      ...                                           0.576496
# 2      ...                                          -0.122642
# 3      ...                                           1.073800
# 4      ...                                          -1.840433
# ...    ...                                                ...
# 12740  ...                                          -0.091298
# 12741  ...                                           0.122227
# 12742  ...                                           0.300775
# 12743  ...                                           0.201650
# 12744  ...                                           0.013106
#
#        Nuclei_Texture_InverseDifferenceMoment_Mitochondria_3_02_256  \
# 0                                              -0.193998
# 1                                              -0.597528
# 2                                              -0.335860
# 3                                               0.186419
# 4                                              -0.898629
# ...                                                  ...
# 12740                                          -0.873547
# 12741                                           0.542332
# 12742                                           0.343652
# 12743                                          -0.039783
# 12744                                           0.349999
#
#        Nuclei_Texture_InverseDifferenceMoment_PM_3_00_256  \
# 0                                              -1.341353
# 1                                              -0.466982
# 2                                              -1.178249
# 3                                              -0.617624
# 4                                              -3.007854
# ...                                                  ...
# 12740                                           0.682969
# 12741                                           1.149501
# 12742                                           1.043567
# 12743                                           1.783126
# 12744                                           1.085568
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_01_256  \
# 0                                              -1.567895
# 1                                              -1.171463
# 2                                              -1.535571
# 3                                              -0.617239
# 4                                              -2.261437
# ...                                                  ...
# 12740                                           0.574117
# 12741                                           1.559534
# 12742                                           0.690879
# 12743                                           1.074292
# 12744                                           0.955515
#
#       Nuclei_Texture_InverseDifferenceMoment_PM_3_02_256  \
# 0                                              -1.016783
# 1                                              -1.227143
# 2                                              -1.945756
# 3                                              -0.817707
# 4                                              -1.966258
# ...                                                  ...
# 12740                                          -0.432044
# 12741                                           1.660693
# 12742                                           0.667793
# 12743                                           1.590732
# 12744                                           1.373375
#
#        Nuclei_Texture_InverseDifferenceMoment_PM_3_03_256  \
# 0                                              -0.458814
# 1                                              -0.726231
# 2                                              -1.693778
# 3                                              -0.839122
# 4                                              -2.988221
# ...                                                  ...
# 12740                                          -0.897299
# 12741                                           0.739464
# 12742                                           0.916731
# 12743                                           2.034789
# 12744                                           1.231035
#
#        Nuclei_Texture_SumEntropy_ER_3_01_256  \
# 0                                  -1.204973
# 1                                   0.424683
# 2                                   0.351037
# 3                                   0.512584
# 4                                   1.908337
# ...                                      ...
# 12740                               1.079783
# 12741                               0.360899
# 12742                              -0.750455
# 12743                              -0.494963
# 12744                              -0.377575
#
#        Nuclei_Texture_SumEntropy_PM_3_01_256  \
# 0                                   0.862746
# 1                                   0.636566
# 2                                   1.328957
# 3                                   0.826657
# 4                                   2.976366
# ...                                      ...
# 12740                               0.476488
# 12741                              -0.410276
# 12742                              -1.054385
# 12743                              -1.367199
# 12744                              -0.490764
#
#        Nuclei_Texture_SumVariance_ER_3_03_256  \
# 0                                   -0.403362
# 1                                   -0.141388
# 2                                   -0.111777
# 3                                   -0.192221
# 4                                    0.735491
# ...                                       ...
# 12740                                0.152047
# 12741                               -0.231493
# 12742                               -0.349051
# 12743                               -0.372645
# 12744                               -0.262981
#
#       Nuclei_Texture_SumVariance_PM_3_03_256
# 0                                  -0.029791
# 1                                  -0.101903
# 2                                   0.202530
# 3                                  -0.077873
# 4                                   2.659667
# ...                                      ...
# 12740                              -0.212762
# 12741                              -0.366330
# 12742                              -0.404095
# 12743                              -0.433355
# 12744                              -0.348631
#
# [12745 rows x 641 columns]}

# %% [markdown]
# ## For each dataframe, take only the DMSO cells and split 70/30 for training and testing

# %%
# Set random state as 0 (same as the rest of the notebook)
random_state = 0

# Set the ratio of the test data to 30% (training data will be 70%)
test_ratio = 0.30

for plate, df in feature_selected_dfs_dict.items():
    # Filter only the rows with DMSO treatment for model training and testing
    DMSO_df = df[df.Metadata_treatment == "DMSO"]
    print(f"Plate: {plate} contains {DMSO_df.shape[0]} DMSO profiles")

    # Split data into training and test sets
    train_df, test_df = train_test_split(
        DMSO_df,
        test_size=test_ratio,
        stratify=DMSO_df[["Metadata_cell_type"]],
        random_state=random_state,
    )

    # Print the shapes of the training and testing data
    print(f"Training data shape: {train_df.shape}")
    print(f"Testing data shape: {test_df.shape}")

    # Save training and test data
    train_df.to_parquet(output_dir / f"{plate}_train.parquet")
    test_df.to_parquet(output_dir / f"{plate}_test.parquet")
# Out:
# Plate: localhost240928120001 contains 1573 DMSO profiles
# Training data shape: (1101, 641)
# Testing data shape: (472, 641)
# Plate: localhost240927060001 contains 1526 DMSO profiles
# Training data shape: (1068, 652)
# Testing data shape: (458, 652)
# Plate: localhost240927120001 contains 1514 DMSO profiles
# Training data shape: (1059, 684)
# Testing data shape: (455, 684)
# Plate: localhost240926150001 contains 2022 DMSO profiles
# Training data shape: (1415, 657)
# Testing data shape: (607, 657)

# %% [markdown]
# ## Combine the 4 plates together using the common morphology features

# %%
# Identify common feature columns (excluding Metadata_ columns)
common_features = set.intersection(*[
    set(df.columns[~df.columns.str.startswith("Metadata_")]) 
    for df in feature_selected_dfs_dict.values()
])

# Concat all filtered dataframes while keeping Metadata columns
combined_df = pd.concat(
    [df[list(common_features) + [col for col in df.columns if col.startswith("Metadata_")]] 
     for df in feature_selected_dfs_dict.values()],
    ignore_index=True
)

print(combined_df.shape)
combined_df.head()
# Out:
# (54610, 494)
#    Cells_Texture_Correlation_PM_3_03_256  \
# 0                               0.558955
# 1                               0.153794
# 2                              -0.895822
# 3                               0.486792
# 4                              -0.544021
#
#    Cells_Intensity_IntegratedIntensityEdge_PM  \
# 0                                    1.586534
# 1                                    1.575170
# 2                                    1.739962
# 3                                    0.505123
# 4                                    0.796886
#
#    Cells_Texture_Correlation_Hoechst_3_02_256  \
# 0                                    0.761087
# 1                                    0.349604
# 2                                   -0.340866
# 3                                    0.317325
# 4                                    0.493012
#
#    Cells_RadialDistribution_RadialCV_PM_4of4  \
# 0                                  -0.083550
# 1                                  -1.163928
# 2                                  -1.091112
# 3                                  -0.826691
# 4                                  -0.475095
#
#    Nuclei_Intensity_IntegratedIntensityEdge_Mitochondria  \
# 0                                          -0.935522
# 1                                          -0.403699
# 2                                          -0.506543
# 3                                          -0.806719
# 4                                           0.246624
#
#    Nuclei_Texture_Correlation_Hoechst_3_03_256  \
# 0                                     0.073294
# 1                                     1.236566
# 2                                     0.061749
# 3                                    -0.703684
# 4                                     1.461370
#
#    Cytoplasm_Texture_InfoMeas1_Hoechst_3_00_256  Nuclei_AreaShape_Zernike_3_1  \
# 0                                     -0.342113                      0.023656
# 1                                      0.191088                     -0.889207
# 2                                      0.918389                      0.899627
# 3                                     -0.304492                     -0.702015
# 4                                      1.714124                      1.796197
#
#    Nuclei_Intensity_MADIntensity_PM  Cells_AreaShape_Zernike_6_0  ...  \
# 0                          0.119329                    -0.543098  ...
# 1                          0.178704                    -0.953293  ...
# 2                          0.404541                    -0.990414  ...
# 3                          0.330322                     1.859774  ...
# 4                          2.563246                    -0.192049  ...
#
#    Metadata_Cells_Location_Center_Y  Metadata_Image_Count_Cells  \
# 0                        268.256144                           9
# 1                        204.845356                           4
# 2                        333.104966                           9
# 3                         88.534307                          18
# 4                         96.955249                          10
#
#    Metadata_ImageNumber         Metadata_Plate  Metadata_Well  \
# 0                     2  localhost240928120001            B02
# 1                     3  localhost240928120001            B02
# 2                     5  localhost240928120001            B02
# 3                     7  localhost240928120001            B02
# 4                     1  localhost240928120001            B02
#
#    Metadata_Cells_Number_Object_Number  Metadata_Cytoplasm_Parent_Cells  \
# 0                                    1                                1
# 1                                    1                                1
# 2                                    1                                1
# 3                                    1                                1
# 4                                    1                                1
#
#    Metadata_Cytoplasm_Parent_Nuclei  Metadata_Nuclei_Number_Object_Number  \
# 0                                 6                                     6
# 1                                 3                                     3
# 2                                 3                                     3
# 3                                 3                                     3
# 4                                 4                                     4
#
#    Metadata_Site
# 0            f04
# 1            f10
# 2            f14
# 3            f18
# 4            f00
#
# [5 rows x 494 columns]

# %% [markdown]
# ## Filter combined dataframe for only DMSO treated cells and split into training and testing dataframes

# %%
# Set random state as 0 (same as the rest of the notebook)
random_state = 0

# Set the ratio of the test data to 30% (training data will be 70%)
test_ratio = 0.30

# Filter only the DMSO treated cells
DMSO_combined_df = combined_df[combined_df.Metadata_treatment == "DMSO"]

# Split the combined data into training and test
training_data, testing_data = train_test_split(
    DMSO_combined_df,
    test_size=test_ratio,
    stratify=DMSO_combined_df[["Metadata_cell_type"]],
    random_state=random_state,
)

# View shapes and example output
print("The testing data contains", testing_data.shape[0], "single-cells.")
print("The training data contains", training_data.shape[0], "single-cells.")

# Save training and test data
training_data.to_parquet(output_dir / "combined_batch1_train.parquet")
testing_data.to_parquet(output_dir / "combined_batch1_test.parquet")

testing_data.head()
# Out:
# The testing data contains 1991 single-cells.
# The training data contains 4644 single-cells.
#        Cells_Texture_Correlation_PM_3_03_256  \
# 20878                               0.643089
# 39718                               0.515605
# 26235                               0.661925
# 19207                               0.260102
# 25233                               1.133778
#
#        Cells_Intensity_IntegratedIntensityEdge_PM  \
# 20878                                   -0.987517
# 39718                                   -0.200370
# 26235                                   -0.151658
# 19207                                    0.005521
# 25233                                    2.631057
#
#        Cells_Texture_Correlation_Hoechst_3_02_256  \
# 20878                                    0.212148
# 39718                                    1.380977
# 26235                                    0.968283
# 19207                                   -0.014662
# 25233                                    1.673325
#
#        Cells_RadialDistribution_RadialCV_PM_4of4  \
# 20878                                  -0.023320
# 39718                                   0.836508
# 26235                                  -0.347531
# 19207                                  -1.281440
# 25233                                   1.032913
#
#        Nuclei_Intensity_IntegratedIntensityEdge_Mitochondria  \
# 20878                                          -0.747686
# 39718                                           0.237170
# 26235                                          -0.251971
# 19207                                           0.171277
# 25233                                           4.973389
#
#        Nuclei_Texture_Correlation_Hoechst_3_03_256  \
# 20878                                     0.998117
# 39718                                     0.785418
# 26235                                    -0.852752
# 19207                                    -0.625947
# 25233                                     2.305920
#
#        Cytoplasm_Texture_InfoMeas1_Hoechst_3_00_256  \
# 20878                                      0.256104
# 39718                                      0.013624
# 26235                                     -0.054869
# 19207                                     -1.738076
# 25233                                     -0.835579
#
#        Nuclei_AreaShape_Zernike_3_1  Nuclei_Intensity_MADIntensity_PM  \
# 20878                     -0.750681                         -0.495985
# 39718                     -0.565253                          0.685659
# 26235                     -0.840579                          0.334713
# 19207                     -0.631204                         -0.421141
# 25233                      0.740312                          1.890899
#
#        Cells_AreaShape_Zernike_6_0  ...  Metadata_Cells_Location_Center_Y  \
# 20878                    -0.575258  ...                        695.687922
# 39718                     0.984653  ...                        735.260532
# 26235                     0.651846  ...                        823.755518
# 19207                    -0.208801  ...                        635.996658
# 25233                    -0.532510  ...                        606.757209
#
#        Metadata_Image_Count_Cells  Metadata_ImageNumber  \
# 20878                          16                   754
# 39718                          22                   153
# 26235                          16                   142
# 19207                          11                   624
# 25233                          23                     3
#
#               Metadata_Plate  Metadata_Well  \
# 20878  localhost240927060001            E11
# 39718  localhost240926150001            B11
# 26235  localhost240927120001            B11
# 19207  localhost240927060001            E05
# 25233  localhost240927120001            B02
#
#        Metadata_Cells_Number_Object_Number  Metadata_Cytoplasm_Parent_Cells  \
# 20878                                   13                               13
# 39718                                   15                               15
# 26235                                   14                               14
# 19207                                    5                                5
# 25233                                   14                               14
#
#        Metadata_Cytoplasm_Parent_Nuclei  Metadata_Nuclei_Number_Object_Number  \
# 20878                                18                                    18
# 39718                                24                                    24
# 26235                                24                                    24
# 19207                                14                                    14
# 25233                                22                                    22
#
#        Metadata_Site
# 20878            f10
# 39718            f08
# 26235            f19
# 19207            f12
# 25233            f10
#
# [5 rows x 494 columns]
