# %% [markdown]
# # Run image QC on data
#
# Note: We load in the CellProfiler QC pipeline to use for this process.

# %% [markdown]
# ## Import libraries

# %%
import pathlib
import pprint

import sys

sys.path.append("../../utils")
import cp_parallel

# %% [markdown]
# ## Set paths and variables

# %% [markdown]
# ### Set the constants

# %%
# set the run type for the parallelization
run_name = "image_qc"

# batch to process
batch = "batch_3"

# %% [markdown]
# ### Set up paths

# %%
# set base directory for where the images are located
base_dir = pathlib.Path(
    f"/media/18tbdrive/CFReT_screening_data/compound_screen/{batch}"
).resolve(strict=True)

# list for plate names
plate_names = []

# iterate through each platemap folder
plate_names = [p.name for p in base_dir.rglob("platemap_*/**/CARD*") if p.is_dir()]

print("There are a total of", len(plate_names), "plates. The names of the plates are:")
for plate in plate_names:
    print(plate)
# Out:
# There are a total of 16 plates. The names of the plates are:
# CARD-CelIns-CX7_260103110001
# CARD-CelIns-CX7_260105100001
# CARD-CelIns-CX7_260104140001
# CARD-CelIns-CX7_260103180001
# CARD-CelIns-CX7_260102130001
# CARD-CelIns-CX7_251230180001
# CARD-CelIns-CX7_251231100001
# CARD-CelIns-CX7_251230110001
# CARD-CelIns-CX7_251217120001
# CARD-CelIns-CX7_251216110001
# CARD-CelIns-CX7_251216180001
# CARD-CelIns-CX7_251215140002
# CARD-CelIns-CX7_251217190001
# CARD-CelIns-CX7_251220120001
# CARD-CelIns-CX7_251229110001
# CARD-CelIns-CX7_251219170001

# %% [markdown]
# ## Create dictionary with all plate data to run CellProfiler in parallel

# %%
# set path to the illum pipeline
path_to_pipeline = pathlib.Path("./pipeline/image_qc.cppipe").resolve(strict=True)

# set main output dir for all plates
output_dir = pathlib.Path("./qc_results").resolve(strict=False)
output_dir.mkdir(exist_ok=True)

# create plate info dictionary
plate_info_dictionary = {}

# recursively find all CARD* folders under platemap_*
for plate_folder in base_dir.rglob("platemap_*/**/CARD*"):
    if plate_folder.is_dir():
        # determine the parent platemap folder name
        platemap_folder_name = plate_folder.parents[
            1
        ].name  # 1 level up from plate_folder inside rglob pattern

        # create nested output dir: Corrected_Images/platemap_#/plate
        plate_output_dir = output_dir / platemap_folder_name / plate_folder.name

        # only create output dir if it doesn't exist or is empty
        if not plate_output_dir.exists() or not any(plate_output_dir.iterdir()):
            plate_output_dir.mkdir(parents=True, exist_ok=True)

            # add info to dictionary
            plate_info_dictionary[plate_folder.name] = {
                "path_to_images": plate_folder.resolve(strict=True),
                "path_to_output": plate_output_dir.resolve(strict=True),
                "path_to_pipeline": path_to_pipeline,
            }
        else:
            print(
                f"{plate_output_dir} already exists and contains files, skipping creation and dictionary."
            )

# view the dictionary
pprint.pprint(plate_info_dictionary, indent=4)
# Out:
# {   'CARD-CelIns-CX7_251215140002': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_5/5a/CARD-CelIns-CX7_251215140002'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_5/CARD-CelIns-CX7_251215140002'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_251216110001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_5/5b/CARD-CelIns-CX7_251216110001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_5/CARD-CelIns-CX7_251216110001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_251216180001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_5/5c/CARD-CelIns-CX7_251216180001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_5/CARD-CelIns-CX7_251216180001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_251217120001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_5/5d/CARD-CelIns-CX7_251217120001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_5/CARD-CelIns-CX7_251217120001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_251217190001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_6/6a/CARD-CelIns-CX7_251217190001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_6/CARD-CelIns-CX7_251217190001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_251219170001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_6/6b/CARD-CelIns-CX7_251219170001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_6/CARD-CelIns-CX7_251219170001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_251220120001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_6/6c/CARD-CelIns-CX7_251220120001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_6/CARD-CelIns-CX7_251220120001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_251229110001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_6/6d/CARD-CelIns-CX7_251229110001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_6/CARD-CelIns-CX7_251229110001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_251230110001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_7/7a/CARD-CelIns-CX7_251230110001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_7/CARD-CelIns-CX7_251230110001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_251230180001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_7/7b/CARD-CelIns-CX7_251230180001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_7/CARD-CelIns-CX7_251230180001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_251231100001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_7/7c/CARD-CelIns-CX7_251231100001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_7/CARD-CelIns-CX7_251231100001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_260102130001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_7/7d/CARD-CelIns-CX7_260102130001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_7/CARD-CelIns-CX7_260102130001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_260103110001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_8/8a/CARD-CelIns-CX7_260103110001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_8/CARD-CelIns-CX7_260103110001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_260103180001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_8/8b/CARD-CelIns-CX7_260103180001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_8/CARD-CelIns-CX7_260103180001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_260104140001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_8/8c/CARD-CelIns-CX7_260104140001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_8/CARD-CelIns-CX7_260104140001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')},
#     'CARD-CelIns-CX7_260105100001': {   'path_to_images': PosixPath('/media/18tbdrive/CFReT_screening_data/compound_screen/batch_2/platemap_8/8d/CARD-CelIns-CX7_260105100001'),
#                                         'path_to_output': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/qc_results/platemap_8/CARD-CelIns-CX7_260105100001'),
#                                         'path_to_pipeline': PosixPath('/home/jenna/targeted_fibrosis_drug_screen/1.illumination_correction/qc_update/pipeline/image_qc.cppipe')}}

# %% [markdown]
# ## Run CellProfiler Parallel
#
# Note: We do not run this code cell as we will run this process through the script.

# %%
# if dictionary is not empty, run CellProfiler in parallel
if plate_info_dictionary:
    cp_parallel.run_cellprofiler_parallel(
        plate_info_dictionary=plate_info_dictionary, run_name=run_name, group_level="plate"
    )
else:
    print("No new plates to process. Exiting script.")
