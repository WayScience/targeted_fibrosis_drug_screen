# %% [markdown]
# # Visualize the UMAP embeddings with labels

# %% [markdown]
# ## Import libraries

# %%
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(arrow))
suppressPackageStartupMessages(library(ggExtra))
source("./plot_themes.r")
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.2.3”
# Warning message:
# “package ‘arrow’ was built under R version 4.2.3”
# Warning message:
# “package ‘ggExtra’ was built under R version 4.2.3”

# %%
# Set up output directory for UMAP figures
output_fig_dir <- file.path("figures", "UMAPs")
dir.create(output_fig_dir, recursive = TRUE, showWarnings = FALSE)

# Set directory and file structure
umap_dir <- "results"
umap_files <- list.files(umap_dir, pattern = "\\.parquet$", recursive = TRUE, full.names = TRUE)

# Build a small table of UMAP files with their platemap directories
umap_info <- data.frame(
  umap_file = umap_files,
  umap_basename = basename(umap_files),
  platemap = basename(dirname(umap_files)),
  stringsAsFactors = FALSE
)

# Make sure each platemap output directory exists
for (platemap_name in unique(umap_info$platemap)) {
  dir.create(file.path(output_fig_dir, platemap_name), recursive = TRUE, showWarnings = FALSE)
}

# Define output figure roots for each UMAP parquet file
umap_info$output_root <- file.path(
  output_fig_dir,
  umap_info$platemap,
  gsub("\\.parquet$", "", umap_info$umap_basename)
)
output_umap_files <- setNames(umap_info$output_root, umap_info$umap_file)

# Print the mapping in a cleaner format
cat("Mapping of input files to output paths:\n")
formatted_output <- data.frame(
  UMAP_File = umap_info$umap_file,
  Platemap = umap_info$platemap,
  Output_Path = umap_info$output_root,
  stringsAsFactors = FALSE
)
print(formatted_output, row.names = FALSE)
# Out:
# Mapping of input files to output paths:
#                                                              UMAP_File
#    results/batch_1/platemap_1/UMAP_combined_batch_1_platemap_1.parquet
#    results/batch_1/platemap_2/UMAP_combined_batch_1_platemap_2.parquet
#    results/batch_1/platemap_3/UMAP_combined_batch_1_platemap_3.parquet
#    results/batch_1/platemap_4/UMAP_combined_batch_1_platemap_4.parquet
#    results/batch_2/platemap_5/UMAP_combined_batch_2_platemap_5.parquet
#    results/batch_2/platemap_6/UMAP_combined_batch_2_platemap_6.parquet
#    results/batch_2/platemap_7/UMAP_combined_batch_2_platemap_7.parquet
#    results/batch_2/platemap_8/UMAP_combined_batch_2_platemap_8.parquet
#  results/batch_3/platemap_10/UMAP_combined_batch_3_platemap_10.parquet
#  results/batch_3/platemap_11/UMAP_combined_batch_3_platemap_11.parquet
#    results/batch_3/platemap_9/UMAP_combined_batch_3_platemap_9.parquet
#     Platemap                                                 Output_Path
#   platemap_1   figures/UMAPs/platemap_1/UMAP_combined_batch_1_platemap_1
#   platemap_2   figures/UMAPs/platemap_2/UMAP_combined_batch_1_platemap_2
#   platemap_3   figures/UMAPs/platemap_3/UMAP_combined_batch_1_platemap_3
#   platemap_4   figures/UMAPs/platemap_4/UMAP_combined_batch_1_platemap_4
#   platemap_5   figures/UMAPs/platemap_5/UMAP_combined_batch_2_platemap_5
#   platemap_6   figures/UMAPs/platemap_6/UMAP_combined_batch_2_platemap_6
#   platemap_7   figures/UMAPs/platemap_7/UMAP_combined_batch_2_platemap_7
#   platemap_8   figures/UMAPs/platemap_8/UMAP_combined_batch_2_platemap_8
#  platemap_10 figures/UMAPs/platemap_10/UMAP_combined_batch_3_platemap_10
#  platemap_11 figures/UMAPs/platemap_11/UMAP_combined_batch_3_platemap_11
#   platemap_9   figures/UMAPs/platemap_9/UMAP_combined_batch_3_platemap_9

# %%
# Load data
umap_cp_df <- list()

for (umap_file in umap_info$umap_file) {
    if (file.exists(umap_file)) {
        # Load the umap data directly from Parquet file
        df <- arrow::read_parquet(umap_file)
         
        # Group by Metadata_Well and count cells
        cell_count_df <- df %>%
            dplyr::group_by(Metadata_Well) %>%
            dplyr::count() %>%
            dplyr::rename(Metadata_Cell_Count = n)
        
        # Merge the cell count data with the original dataframe
        key <- umap_file
        umap_cp_df[[key]] <- df %>%
            dplyr::left_join(cell_count_df, by = "Metadata_Well")
        
        # Update 'Endocrinology & Hormones' in Metadata_Pathway
        umap_cp_df[[key]] <- umap_cp_df[[key]] %>%
            dplyr::mutate(Metadata_Pathway = dplyr::recode(Metadata_Pathway,
                                                           "Endocrinology & Hormones" = "Endocrinology &\nHormones"))
            
    } else {
        message(paste("No file found:", umap_file))
    }
}

# Inspect the first processed plate's data and print its dimensions
if (length(umap_cp_df) > 0) {
    file_to_inspect <- names(umap_cp_df)[1]
    df_to_inspect <- umap_cp_df[[file_to_inspect]]
    print(paste("Inspecting file:", file_to_inspect))
    print(paste("Dimensions:", dim(df_to_inspect)[1], "rows x", dim(df_to_inspect)[2], "columns"))
    head(df_to_inspect)
}
# Out:
# [1] "Inspecting file: results/batch_1/platemap_1/UMAP_combined_batch_1_platemap_1.parquet"
# [1] "Dimensions: 33150 rows x 28 columns"
#   Metadata_WellCol Metadata_Cells_Location_Center_X
# 1 2                473.3629
# 2 2                752.9529
# 3 2                536.9766
# 4 2                727.9239
# 5 2                534.5185
# 6 2                350.1216
#   Metadata_Nuclei_Location_Center_X Metadata_Cells_Location_Center_Y
# 1 458.5781                          225.8467
# 2 758.7897                          153.2149
# 3 528.2829                          162.8489
# 4 706.9761                          145.3519
# 5 523.0542                          191.2995
# 6 341.2289                          319.9368
#   Metadata_Well Metadata_Cells_Number_Object_Number
# 1 B02           1
# 2 B02           1
# 3 B02           1
# 4 B02           1
# 5 B02           1
# 6 B02           1
#   Metadata_cqc_failed_small_cells Metadata_heart_failure_type
# 1 FALSE                           NA
# 2 FALSE                           NA
# 3 FALSE                           NA
# 4 FALSE                           NA
# 5 FALSE                           NA
# 6 FALSE                           NA
#   Metadata_cell_type Metadata_ImageNumber ⋯
# 1 healthy             7                   ⋯
# 2 healthy            19                   ⋯
# 3 healthy             4                   ⋯
# 4 healthy            16                   ⋯
# 5 healthy            21                   ⋯
# 6 healthy            22                   ⋯
#   Metadata_Nuclei_Number_Object_Number Metadata_Plate
# 1 1                                    CARD-CelIns-CX7_251023210001
# 2 1                                    CARD-CelIns-CX7_251023210001
# 3 2                                    CARD-CelIns-CX7_251023210001
# 4 2                                    CARD-CelIns-CX7_251023210001
# 5 2                                    CARD-CelIns-CX7_251023210001
# 6 2                                    CARD-CelIns-CX7_251023210001
#   Metadata_Image_Count_Cells Metadata_cqc_failed_blurry_cells
# 1  5                         FALSE
# 2  5                         FALSE
# 3 19                         FALSE
# 4 14                         FALSE
# 5  7                         FALSE
# 6  3                         FALSE
#   Metadata_heart_number Metadata_cqc_failed_oversegmented_nuclei UMAP0
# 1 7                     FALSE                                    -1.4150804
# 2 7                     FALSE                                     0.4971248
# 3 7                     FALSE                                    -2.3712986
# 4 7                     FALSE                                    -1.4737856
# 5 7                     FALSE                                    -2.3629012
# 6 7                     FALSE                                    -1.3291773
#   UMAP1    Metadata_treatment_type Metadata_Cell_Count
# 1 7.648829 healthy + DMSO          753
# 2 6.433891 healthy + DMSO          753
# 3 9.556107 healthy + DMSO          753
# 4 4.918817 healthy + DMSO          753
# 5 9.180634 healthy + DMSO          753
# 6 5.983180 healthy + DMSO          753

# %%
umap_combined_bulk_files <- grep(
    "UMAP_combined_bulk",
    names(umap_cp_df),
    value = TRUE,
    ignore.case = TRUE
)

selected_key <- if (length(umap_combined_bulk_files) > 0) {
    umap_combined_bulk_files[1]
} else {
    message("No UMAP_combined_bulk profile found; inspecting the first available UMAP profile instead.")
    names(umap_cp_df)[1]
}

selected_df <- umap_cp_df[[selected_key]]

cat("Inspecting UMAP profile:", selected_key, "\n")
cat("Dimensions:", nrow(selected_df), "rows x", ncol(selected_df), "columns\n\n")

cat("Column names:\n")
print(names(selected_df))
cat("\nFirst 6 rows:\n")
print(head(selected_df))

cat("\nCounts by Metadata_treatment_type:\n")
print(selected_df %>%
    dplyr::count(Metadata_treatment_type) %>%
    dplyr::arrange(desc(n)))

cat("\nUnique Metadata_Pathway values (up to 10):\n")
print(unique(selected_df$Metadata_Pathway)[1:min(10, length(unique(selected_df$Metadata_Pathway)))])
# Out:
# No UMAP_combined_bulk profile found; inspecting the first available UMAP profile instead.
# Inspecting UMAP profile: results/batch_1/platemap_1/UMAP_combined_batch_1_platemap_1.parquet
# Dimensions: 33150 rows x 28 columns
#
# Column names:
#  [1] "Metadata_WellCol"
#  [2] "Metadata_Cells_Location_Center_X"
#  [3] "Metadata_Nuclei_Location_Center_X"
#  [4] "Metadata_Cells_Location_Center_Y"
#  [5] "Metadata_Well"
#  [6] "Metadata_Cells_Number_Object_Number"
#  [7] "Metadata_cqc_failed_small_cells"
#  [8] "Metadata_heart_failure_type"
#  [9] "Metadata_cell_type"
# [10] "Metadata_ImageNumber"
# [11] "Metadata_Cytoplasm_Parent_Cells"
# [12] "Metadata_Nuclei_Location_Center_Y"
# [13] "Metadata_treatment"
# [14] "Metadata_Pathway"
# [15] "Metadata_cqc_failed_low_intensity"
# [16] "Metadata_Site"
# [17] "Metadata_Cytoplasm_Parent_Nuclei"
# [18] "Metadata_WellRow"
# [19] "Metadata_Nuclei_Number_Object_Number"
# [20] "Metadata_Plate"
# [21] "Metadata_Image_Count_Cells"
# [22] "Metadata_cqc_failed_blurry_cells"
# [23] "Metadata_heart_number"
# [24] "Metadata_cqc_failed_oversegmented_nuclei"
# [25] "UMAP0"
# [26] "UMAP1"
# [27] "Metadata_treatment_type"
# [28] "Metadata_Cell_Count"
#
# First 6 rows:
# # A tibble: 6 × 28
#   Metadata_WellCol Metadata_Cells_Location_Center_X Metadata_Nuclei_Location_C…¹
#              <int>                            <dbl>                        <dbl>
# 1                2                             473.                         459.
# 2                2                             753.                         759.
# 3                2                             537.                         528.
# 4                2                             728.                         707.
# 5                2                             535.                         523.
# 6                2                             350.                         341.
# # ℹ abbreviated name: ¹​Metadata_Nuclei_Location_Center_X
# # ℹ 25 more variables: Metadata_Cells_Location_Center_Y <dbl>,
# #   Metadata_Well <chr>, Metadata_Cells_Number_Object_Number <int>,
# #   Metadata_cqc_failed_small_cells <lgl>, Metadata_heart_failure_type <chr>,
# #   Metadata_cell_type <chr>, Metadata_ImageNumber <int>,
# #   Metadata_Cytoplasm_Parent_Cells <int>,
# #   Metadata_Nuclei_Location_Center_Y <dbl>, Metadata_treatment <chr>, …
#
# Counts by Metadata_treatment_type:
# # A tibble: 3 × 2
#   Metadata_treatment_type     n
#   <chr>                   <int>
# 1 failing + compound      26564
# 2 failing + DMSO           3367
# 3 healthy + DMSO           3219
#
# Unique Metadata_Pathway values (up to 10):
#  [1] "healthy + DMSO"            "Apoptosis"
#  [3] "Angiogenesis"              "Others"
#  [5] "Endocrinology &\nHormones" "Neuronal Signaling"
#  [7] "DNA Damage"                "Stem Cells & Wnt"
#  [9] "failing + DMSO"            "Metabolism"

# %% [markdown]
# ## Cell type only UMAP

# %%
for (plate in names(umap_cp_df)) {
    # cell type UMAP
    output_file <- output_umap_files[[plate]]
    output_file <- paste0(output_file, "_cell_type.png")
    
    umap_dose_gg <- (
        ggplot(umap_cp_df[[plate]], aes(x = UMAP0, y = UMAP1))
        + geom_point(
            aes(color = Metadata_treatment_type), size = 0.4, alpha = 0.7
        )
        + facet_grid(Metadata_treatment_type ~ .)
        + theme_bw()
        + scale_color_brewer(palette = "Dark2", name = "Cell type")
        + theme(legend.position = "none")

    )
    
    ggsave(output_file, umap_dose_gg, dpi = 500, height = 6, width = 3)
}

# %% [markdown]
# ## Failing versus healthy only UMAP

# %%
for (plate in names(umap_cp_df)) {
    # Filter data for the two treatment types
    filtered_df <- umap_cp_df[[plate]] %>%
        dplyr::filter(Metadata_treatment_type %in% c("healthy + DMSO", "failing + DMSO"))
    
    # Generate output file path
    output_file <- output_umap_files[[plate]]
    output_file <- paste0(output_file, "_healthy_failing.png")
    
    # Create UMAP plot
    umap_gg <- (
        ggplot(filtered_df, aes(x = UMAP0, y = UMAP1))
        + geom_point(
            aes(color = Metadata_treatment_type), size = 0.4, alpha = 0.7
        )
        + theme_bw()
        + facet_wrap(~ Metadata_treatment_type, nrow = 1)
        + scale_color_manual(values = c("healthy + DMSO" = "#004400", "failing + DMSO" = "#a0004b"), name = "Treatment Type")
        + theme(legend.position = "none")
    )
    
    # Save the plot
    ggsave(output_file, umap_gg, dpi = 500, height = 4, width = 6)
}

# %%
highlight_ids <- c(
  "UCD-0001921","UCD-0001812","UCD-0159268","UCD-0159406",
  "UCD-0000841","UCD-0159442","UCD-0001419","UCD-0159486","UCD-0159487"
)

for (plate in names(umap_cp_df)) {

    output_file <- output_umap_files[[plate]]
    output_file <- paste0(output_file, "_pathway.png")

    df <- umap_cp_df[[plate]]

    # detect bulk UMAP (for dot size scaling)
    is_bulk <- any(grepl("UMAP_combined_bulk", colnames(df)))

    # create combined color logic (highlights override everything else)
    df$color_group <- ifelse(
        df$Metadata_treatment %in% highlight_ids,
        df$Metadata_treatment,
        df$Metadata_Pathway
    )

    # determine which highlighted compounds are actually present
    present_highlights <- intersect(
        highlight_ids,
        unique(df$Metadata_treatment)
    )

    # Reorder Metadata_Pathway to put DMSO controls first
    df$Metadata_Pathway <- factor(
        df$Metadata_Pathway,
        levels = c(
            "healthy + DMSO",
            "failing + DMSO",
            setdiff(unique(df$Metadata_Pathway), c("healthy + DMSO", "failing + DMSO"))
        )
    )

    # dynamic point sizing
    point_size <- if (is_bulk) 2.8 else 0.3

    # Dynamic figure sizing based on number of facets
    n_facets <- length(unique(df$Metadata_Pathway))

    plot_height <- if (n_facets <= 13) {
        10
    } else if (n_facets <= 18) {
        12
    } else {
        14
    }

    plot_width <- 10

    umap_dose_gg <- (
        ggplot(df, aes(x = UMAP0, y = UMAP1))

        + geom_point(
            aes(color = color_group),
            size = point_size,
            alpha = 0.7
        )

        + facet_wrap(~Metadata_Pathway, ncol = 4)

        + theme_bw()

        + scale_color_manual(
            values = highlight_colors,
            breaks = present_highlights,
            name = "Hit compound(s)"
        )

        + guides(
            color = guide_legend(
                override.aes = list(
                    size = 4,
                    alpha = 1
                )
            )
        )

        + theme(
            legend.position = "right",
            legend.title = element_text(size = 10),
            legend.text = element_text(size = 8),
            strip.text = element_text(size = 10),
            strip.background = element_rect(fill = "grey90", color = NA),
            panel.spacing = unit(0.6, "lines")
        )
    )

    ggsave(
        output_file,
        umap_dose_gg,
        dpi = 600,
        height = plot_height,
        width = plot_width
    )
}
